# %% [markdown]
# ## Crawling Berita

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# URL dasar situs berita Detik
base_url = "https://news.detik.com"

def get_news_detail(link):
    """Ambil isi berita dari halaman detail"""
    try:
        res = requests.get(link, timeout=10)
        res.raise_for_status()
        soup = BeautifulSoup(res.text, 'html.parser')

        # Ambil isi paragraf berita
        body = soup.find('div', class_='detail__body-text itp_bodycontent')
        if not body:
            return "", ""
        paragraphs = body.find_all('p')
        content = "\n".join([p.get_text(strip=True) for p in paragraphs])

        # Ambil kategori berita (nama rubrik)
        breadcrumb = soup.find('div', class_='breadcrumb')
        category = breadcrumb.find_all('a')[1].text.strip() if breadcrumb and len(breadcrumb.find_all('a')) > 1 else "Tidak diketahui"

        return content, category
    except Exception as e:
        print(f"Gagal ambil detail: {link}, error: {e}")
        return "", "Tidak diketahui"

def scrape_detik(limit=50):
    """Scraping berita Detik dengan batas tertentu"""
    all_news = []
    page = 1
    id_berita = 1

    while len(all_news) < limit:
        url = f"{base_url}/indeks?page={page}"
        print(f"Scraping halaman {page}...")
        try:
            r = requests.get(url, timeout=10)
            r.raise_for_status()
        except Exception as e:
            print(f"Gagal ambil halaman {page}: {e}")
            break

        soup = BeautifulSoup(r.text, 'html.parser')
        articles = soup.find_all('a', class_='media__link')

        if not articles:
            print("Tidak ada artikel ditemukan, berhenti.")
            break

        for a in articles:
            if len(all_news) >= limit:
                break

            link = a.get('href')
            title = a.get_text(strip=True)

            if link and link.startswith('/'):
                link = base_url + link

            if not link or not title:
                continue

            isi, kategori = get_news_detail(link)
            if not isi:
                continue

            all_news.append({
                'idberita': id_berita,
                'judul_berita': title,
                'isi_berita': isi,
                'kategori_berita': kategori,
                'url': link
            })
            print(f"[{id_berita}] {title}")
            id_berita += 1
            time.sleep(1)  # Hindari pemblokiran server

        page += 1

    return all_news

# Jalankan scraping
news_data = scrape_detik(limit=100)

# Simpan ke CSV
df = pd.DataFrame(news_data)
df.to_csv("berita_detik.csv", index=False, encoding="utf-8-sig")
print("Berhasil menyimpan ke berita_detik.csv")
# Out:
# Scraping halaman 1...
# [1] Rudy Tanoesoedibjo Melawan Usai Jadi Tersangka KPK, Ajukan Praperadilan
# [2] Netanyahu Desak Qatar Usir Hamas: Jika Tidak, Kami Akan Melakukannya!
# [3] Identitas Palsu Sopir Bank Pembawa Kabur Rp 10 Miliar Saat Sembunyi
# [4] Bongkar Jagal Anjing, Polda Riau Dibanjiri Karangan Bunga dari Dog Lovers
# [5] Benny Demokrat: Koalisi Gemuk Tak Harus Buat DPR Pasif
# [6] TNI Bakal Tindak Tegas Prajurit Diduga Terlibat Pembunuhan Kacab Bank
# [7] Ditekan Pemerintah, Kaum Feminis China Teruskan Perlawanan
# [8] Brimob Pemukul Staf KLH di Serang Disanksi Tunda Kenaikan Pangkat-Patsus
# [9] Info Pencairan KJP Plus 2025 Tahap 2 Bulan September, Cek Rinciannya!
# [10] Putra Mahkota Arab Saudi Tegaskan Gaza Milik Palestina!
# Scraping halaman 6...
# [78] Survei BPS: Tingkat Kepuasan Jemaah Haji RI 2025 88,46%, Naik dari Tahun Lalu
# [79] Legislator Harap Tata Kelola Haji Lebih Terintegrasi, Bakal Diawasi Ketat
# [80] Kemensos Gerak Cepat Salurkan Bantuan untuk Korban Banjir Bali
# [81] Kapolda Bali Kerahkan Personel Pastikan Penanganan Banjir-Hak Warga Terpenuhi
# [82] Kejari Lebak Ungkap Korupsi di PDAM Tirta Multatuli, Eks Dirut-Dewas Ditahan
# [83] Korban Tewas Akibat Banjir di Bali Bertambah Jadi 9 Orang, 6 Masih Hilang
# [84] Temuan Baru KPK: Agen Tak Beri Setoran Tak Kebagian Kuota Haji
# [85] Operasi Narkoba di Rohul: 3 Tersangka Dijerat, 24 Paket Sabu Disita
# [86] Kapolda Bali Siapkan Bantuan Trauma Healing untuk Korban Banjir dan Longsor
# [87] Banjir Terjang Bali, Pemkot Denpasar Tetapkan Status Tanggap Darurat Bencana
# [88] Banjir dan Longsor Terjang Bali, Polri Bantu Evakuasi Warga Terdampak
# [89] Bamsoet Ingatkan Dampak Konvergensi Politik dengan Disrupsi Digital
# [90] Anggota BP MPR Soroti Ketimpangan Desentralisasi, Ingatkan Peran Pusat
# Scraping halaman 7...
# [91] Aliansi Ojol Curhat di DPR Minta Potongan Tarif 10% Direalisasikan
# [92] Polisi-TNI dan Imigrasi Tanam Kelapa di Dumai, 'Emas Hijau' untuk Masa Depan
# [93] KPK Perpanjang Waktu Penahanan Eks Wamenaker Noel
# [94] Jaksa Tampilkan Duit Puluhan M di Brankas, Marcella Santoso Klaim Success Fee
# [95] Terkendala Cuaca, Helikopter Jatuh di Jila Mimika Dievakuasi Besok
# [96] Gempa M 4,6 Guncang Sukabumi
# [97] Aksi Polisi Bagikan Air Mineral dan Roti ke Massa Demo Buruh di Monas
# [98] Duka Pulau Dewata Diterjang Banjir hingga Jatuh Korban Jiwa
# [99] Muncul Kode 'Mendan' dan 'DJ' untuk Hakim di Sidang Suap Vonis Onslag Migor
# [100] Ada Perlindungan Adat hingga Iklim, 4 RUU DPD RI Masuk Prolegnas
# Berhasil menyimpan ke berita_detik.csv

# %%
# === BAGIAN 2: Membaca & Menampilkan CSV ===
import pandas as pd

df = pd.read_csv("berita_detik.csv")
print("=== Contoh Data Hasil Crawling ===")
print(df.head(10))  # tampilkan 10 berita pertama

# Jika dijalankan di Jupyter Notebook, bisa menampilkan tabel interaktif:
df.head()
# Out:
# === Contoh Data Hasil Crawling ===
#    idberita                                       judul_berita  \
# 0         1  Rudy Tanoesoedibjo Melawan Usai Jadi Tersangka...
# 1         2  Netanyahu Desak Qatar Usir Hamas: Jika Tidak, ...
# 2         3  Identitas Palsu Sopir Bank Pembawa Kabur Rp 10...
# 3         4  Bongkar Jagal Anjing, Polda Riau Dibanjiri Kar...
# 4         5  Benny Demokrat: Koalisi Gemuk Tak Harus Buat D...
# 5         6  TNI Bakal Tindak Tegas Prajurit Diduga Terliba...
# 6         7  Ditekan Pemerintah, Kaum Feminis China Teruska...
# 7         8  Brimob Pemukul Staf KLH di Serang Disanksi Tun...
# 8         9  Info Pencairan KJP Plus 2025 Tahap 2 Bulan Sep...
# 9        10  Putra Mahkota Arab Saudi Tegaskan Gaza Milik P...
#
#                                           isi_berita  kategori_berita  \
# 0  Komisaris Utama PT Dosni Roha Logistik,Bambang...  Tidak diketahui
# 1  Perdana Menteri (PM) IsraelBenjamin Netanyahum...  Tidak diketahui
# 2  Sopir bank,Anggun Tyas, yang membawa kabur uan...  Tidak diketahui
# 3  Kepolisian Daerah (Polda) Riau melalui Polrest...  Tidak diketahui
# 4  Anggota Komisi III DPR RI, Benny K Harman, men...  Tidak diketahui
# 5  Oknum TNI AD berinisial F diduga terlibat dala...  Tidak diketahui
# 6  Menjelang Hari Perempuan Internasional di tahu...  Tidak diketahui
# 7  Polda Banten telah menggelar sidang etik dan m...  Tidak diketahui
# 8  Pemprov DKI Jakarta mengumumkan pencairanKJP P...  Tidak diketahui
# 9  Putra Mahkota Arab Saudi, Pangeran Mohammed bi...  Tidak diketahui
#
#                                                  url
# 0  https://news.detik.com/berita/d-8106716/rudy-t...
# 1  https://news.detik.com/internasional/d-8106715...
# 2  https://news.detik.com/berita/d-8106703/identi...
# 3  https://news.detik.com/melindungi-tuah-marwah/...
# 4  https://news.detik.com/berita/d-8106679/benny-...
# 5  https://news.detik.com/berita/d-8106664/tni-ba...
# 6  https://news.detik.com/dw/d-8106653/ditekan-pe...
# 7  https://news.detik.com/berita/d-8106640/brimob...
# 8  https://news.detik.com/berita/d-8106632/info-p...
# 9  https://news.detik.com/internasional/d-8106629...
#    idberita                                       judul_berita  \
# 0         1  Rudy Tanoesoedibjo Melawan Usai Jadi Tersangka...
# 1         2  Netanyahu Desak Qatar Usir Hamas: Jika Tidak, ...
# 2         3  Identitas Palsu Sopir Bank Pembawa Kabur Rp 10...
# 3         4  Bongkar Jagal Anjing, Polda Riau Dibanjiri Kar...
# 4         5  Benny Demokrat: Koalisi Gemuk Tak Harus Buat D...
#
#                                           isi_berita  kategori_berita  \
# 0  Komisaris Utama PT Dosni Roha Logistik,Bambang...  Tidak diketahui
# 1  Perdana Menteri (PM) IsraelBenjamin Netanyahum...  Tidak diketahui
# 2  Sopir bank,Anggun Tyas, yang membawa kabur uan...  Tidak diketahui
# 3  Kepolisian Daerah (Polda) Riau melalui Polrest...  Tidak diketahui
# 4  Anggota Komisi III DPR RI, Benny K Harman, men...  Tidak diketahui
#
#                                                  url
# 0  https://news.detik.com/berita/d-8106716/rudy-t...
# 1  https://news.detik.com/internasional/d-8106715...
# 2  https://news.detik.com/berita/d-8106703/identi...
# 3  https://news.detik.com/melindungi-tuah-marwah/...
# 4  https://news.detik.com/berita/d-8106679/benny-...
