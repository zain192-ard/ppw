# %% [markdown]
# # Crawling PTA TRUNOJOYO

# %%
# !pip install builtwith
# !pip install beautifulsoup4
# !pip install pandas
# !pip install tqdm
# !pip install openpyxl
# Out:
# Requirement already satisfied: builtwith in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (1.3.4)
# Requirement already satisfied: six in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from builtwith) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: beautifulsoup4 in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (4.13.2)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tqdm in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openpyxl in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\zain\appdata\local\programs\python\python313\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re

def get_fakultas_prodi_list():
    """
    Fungsi untuk mengambil daftar semua Fakultas dan Prodi di dalamnya.
    Struktur scraping disesuaikan dengan sidebar di mana prodi berada di dalam fakultas.
    """
    prodi_list = []
    try:
        # URL yang berisi sidebar navigasi fakultas dan prodi
        url_nav = "https://pta.trunojoyo.ac.id/c_search/byfac"
        r = requests.get(url_nav)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, "html.parser")
        
        # 1. Targetkan sidebar navigasi utama
        sidebar_nav = soup.select_one('div.box.sidebar_nav')
        if not sidebar_nav:
            print("Sidebar navigasi tidak ditemukan.")
            return []

        # 2. Ambil semua item list <li> dari fakultas (level pertama)
        fakultas_items = sidebar_nav.select_one('ul').find_all('li', recursive=False)
        
        for item_fakultas in fakultas_items:
            # 3. Ambil nama fakultas dari link <a> pertama di dalam <li>
            anchor_fakultas = item_fakultas.find('a', recursive=False)
            if not anchor_fakultas:
                continue
            nama_fakultas = anchor_fakultas.get_text(strip=True)
            
            # 4. Cari daftar <ul> bersarang yang berisi prodi
            ul_prodi = item_fakultas.find('ul')
            if not ul_prodi:
                continue

            # 5. Ambil semua link <a> prodi di dalam daftar bersarang tersebut
            for link_prodi in ul_prodi.select('li a'):
                nama_prodi = link_prodi.get_text(strip=True)
                href = link_prodi.get('href')
                # Ekstrak ID prodi dari URL
                prodi_id = href.strip('/').split('/')[-1]
                
                if prodi_id.isdigit():
                    prodi_list.append({
                        "id_prodi": int(prodi_id),
                        "nama_prodi": nama_prodi,
                        "nama_fakultas": nama_fakultas
                    })
                    
    except requests.exceptions.RequestException as e:
        print(f"Gagal mengambil daftar fakultas dan prodi: {e}")
        
    return prodi_list

def scrape_all():
    """
    Fungsi utama untuk melakukan scraping data dari semua prodi,
    kini dengan informasi fakultas.
    """
    # 1. Dapatkan daftar lengkap prodi beserta fakultasnya
    daftar_prodi_lengkap = get_fakultas_prodi_list()

    if not daftar_prodi_lengkap:
        print("Tidak ada prodi yang bisa di-scrape. Program berhenti.")
        return

    # Inisialisasi dictionary dengan kolom baru "nama_fakultas"
    data = {
        "nama_fakultas": [],
        "id_prodi": [],
        "nama_prodi": [],
        "penulis": [],
        "judul": [],
        "pembimbing_pertama": [],
        "pembimbing_kedua": [],
        "abstrak": [],
        "abstrak_inggris": []
    }

    # 2. Lakukan looping untuk setiap prodi dari daftar yang didapat
    for prodi in daftar_prodi_lengkap:
        prodi_id = prodi["id_prodi"]
        nama_prodi = prodi["nama_prodi"]
        nama_fakultas = prodi["nama_fakultas"]
        page = 1
        jurnal_ditemukan_per_prodi = 0
        
        while True:
            url = f"https://pta.trunojoyo.ac.id/c_search/byprod/{prodi_id}/{page}"
            try:
                r = requests.get(url)
                r.raise_for_status()
                soup = BeautifulSoup(r.content, "html.parser")
                jurnals = soup.select('li[data-cat="#luxury"]')

                if not jurnals:
                    break
                
                jurnal_ditemukan_per_prodi += len(jurnals)

                for jurnal in jurnals:
                    # Proses scraping detail jurnal (tetap sama)
                    jurnal_url = jurnal.select_one('a.gray.button')['href']
                    response = requests.get(jurnal_url)
                    response.raise_for_status()
                    isi = BeautifulSoup(response.content, "html.parser").select_one('div#content_journal')
                    if not isi: continue

                    judul = isi.select_one('a.title').text.strip()
                    penulis = isi.select_one('span:contains("Penulis")').text.split(' : ')[1].strip()
                    pembimbing_pertama = isi.select_one('span:contains("Dosen Pembimbing I")').text.split(' : ')[1].strip()
                    pembimbing_kedua = isi.select_one('span:contains("Dosen Pembimbing II")').text.split(':')[1].strip()
                    # --- PERUBAHAN PADA EKSTRAKSI ABSTRAK ---
                    abstract_paragraphs = isi.select('p[align="justify"]')
                    
                    # Ambil teks mentah dari abstrak Bahasa Indonesia
                    text_indo_mentah = abstract_paragraphs[0].text if len(abstract_paragraphs) > 0 else "Tidak ada abstrak"
                    # 2. BERSIHKAN TEKS MENTAH
                    abstrak_indonesia = re.sub(r'\s+', ' ', text_indo_mentah).strip()

                    # Ambil teks mentah dari abstrak Bahasa Inggris
                    text_inggris_mentah = abstract_paragraphs[1].text if len(abstract_paragraphs) > 1 else "No abstract available"
                    # 2. BERSIHKAN TEKS MENTAH
                    abstrak_inggris = re.sub(r'\s+', ' ', text_inggris_mentah).strip()
                    # --- AKHIR PERUBAHAN ---

                    # Menambahkan semua data ke dictionary
                    data["nama_fakultas"].append(nama_fakultas)
                    data["id_prodi"].append(prodi_id)
                    data["nama_prodi"].append(nama_prodi)
                    data["penulis"].append(penulis)
                    data["judul"].append(judul)
                    data["pembimbing_pertama"].append(pembimbing_pertama)
                    data["pembimbing_kedua"].append(pembimbing_kedua)
                    data["abstrak"].append(abstrak_indonesia)
                    data["abstrak_inggris"].append(abstrak_inggris)
                
                page += 1
                time.sleep(1)

            except requests.exceptions.RequestException as e:
                print(f"Error pada Prodi {nama_prodi} (ID: {prodi_id}) halaman {page}: {e}")
                break
        
        print(f"✔ Selesai: {nama_fakultas} - {nama_prodi} (ID: {prodi_id}) | Total {jurnal_ditemukan_per_prodi} jurnal.")

    df = pd.DataFrame(data)
    df.to_csv("pta_lengkap_fakultas_prodi.csv", index=False)
    print("\n✅ Proses scraping selesai. Data disimpan ke 'pta_lengkap_fakultas_prodi.csv'")
    
    return df

# Untuk menjalankan seluruh proses scraping
# df_final = scrape_all()
# print(df_final.head())

# %%
df_all = scrape_all()
# Out:
# Gagal mengambil daftar fakultas dan prodi: HTTPSConnectionPool(host='pta.trunojoyo.ac.id', port=443): Max retries exceeded with url: /c_search/byfac (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001BDFE616BA0>: Failed to resolve 'pta.trunojoyo.ac.id' ([Errno 11001] getaddrinfo failed)"))
# Tidak ada prodi yang bisa di-scrape. Program berhenti.

# %%
# === BAGIAN 2: Membaca & Menampilkan SEMUA CSV ===
import pandas as pd

# Atur agar semua baris dan kolom ditampilkan
pd.set_option('display.max_rows', None)   # tampilkan semua baris
pd.set_option('display.max_columns', None)  # tampilkan semua kolom (jika banyak)

df = pd.read_csv("pta_lengkap_fakultas_prodi.csv")

print("=== Semua Data Hasil Crawling ===")
print(df)  # tampilkan semua baris

# Jika di Jupyter Notebook dan ingin tampilan tabel penuh:
df
# Out:
# === Semua Data Hasil Crawling ===
#      nama_fakultas  id_prodi                    nama_prodi  \
# 0            Hukum         1                    Ilmu Hukum
# 1            Hukum         1                    Ilmu Hukum
# 2            Hukum         1                    Ilmu Hukum
# 3            Hukum         1                    Ilmu Hukum
# 4            Hukum         1                    Ilmu Hukum
# 5            Hukum         1                    Ilmu Hukum
# 6            Hukum         1                    Ilmu Hukum
# 7            Hukum         1                    Ilmu Hukum
# 8            Hukum         1                    Ilmu Hukum
# 9            Hukum         1                    Ilmu Hukum
# 10           Hukum         1                    Ilmu Hukum
# 11           Hukum         1                    Ilmu Hukum
# 12           Hukum         1                    Ilmu Hukum
# 13           Hukum         1                    Ilmu Hukum
# 14           Hukum         1                    Ilmu Hukum
# 15           Hukum         1                    Ilmu Hukum
# 16           Hukum         1                    Ilmu Hukum
# 17           Hukum         1                    Ilmu Hukum
# 18           Hukum         1                    Ilmu Hukum
# 19           Hukum         1                    Ilmu Hukum
# 20           Hukum         1                    Ilmu Hukum
# 21           Hukum         1                    Ilmu Hukum
# 22           Hukum         1                    Ilmu Hukum
# 23           Hukum         1                    Ilmu Hukum
# 24           Hukum         1                    Ilmu Hukum
# 25           Hukum         1                    Ilmu Hukum
# 26           Hukum         1                    Ilmu Hukum
# 27           Hukum         1                    Ilmu Hukum
# 28           Hukum         1                    Ilmu Hukum
# 29           Hukum         1                    Ilmu Hukum
# 30           Hukum         1                    Ilmu Hukum
# 31           Hukum         1                    Ilmu Hukum
# 32           Hukum         1                    Ilmu Hukum
# 33           Hukum         1                    Ilmu Hukum
# 34           Hukum         1                    Ilmu Hukum
# 35           Hukum         1                    Ilmu Hukum
# 36           Hukum         1                    Ilmu Hukum
# 37           Hukum         1                    Ilmu Hukum
# 38           Hukum         1                    Ilmu Hukum
# 39           Hukum         1                    Ilmu Hukum
# 40           Hukum         1                    Ilmu Hukum
# 41           Hukum         1                    Ilmu Hukum
# 42           Hukum         1                    Ilmu Hukum
# 43           Hukum         1                    Ilmu Hukum
# 44           Hukum         1                    Ilmu Hukum
# 45           Hukum         1                    Ilmu Hukum
# 46           Hukum         1                    Ilmu Hukum
# 47           Hukum         1                    Ilmu Hukum
# 48           Hukum         1                    Ilmu Hukum
# 49           Hukum         1                    Ilmu Hukum
# 50           Hukum         1                    Ilmu Hukum
# 51           Hukum         1                    Ilmu Hukum
# 52           Hukum         1                    Ilmu Hukum
# 53           Hukum         1                    Ilmu Hukum
# 54           Hukum         1                    Ilmu Hukum
# 55           Hukum         1                    Ilmu Hukum
# 56           Hukum         1                    Ilmu Hukum
# 57           Hukum         1                    Ilmu Hukum
# 58           Hukum         1                    Ilmu Hukum
# 59           Hukum         1                    Ilmu Hukum
# 60           Hukum         1                    Ilmu Hukum
# 61           Hukum         1                    Ilmu Hukum
# 62           Hukum         1                    Ilmu Hukum
# 63           Hukum         1                    Ilmu Hukum
# 64           Hukum         1                    Ilmu Hukum
# 65           Hukum         1                    Ilmu Hukum
# 66           Hukum         1                    Ilmu Hukum
# 67           Hukum         1                    Ilmu Hukum
# 68           Hukum         1                    Ilmu Hukum
# 69           Hukum         1                    Ilmu Hukum
# 70           Hukum         1                    Ilmu Hukum
# 71           Hukum         1                    Ilmu Hukum
# 72           Hukum         1                    Ilmu Hukum
# 73           Hukum         1                    Ilmu Hukum
# 74           Hukum         1                    Ilmu Hukum
# 75           Hukum         1                    Ilmu Hukum
# 76           Hukum         1                    Ilmu Hukum
# 77           Hukum         1                    Ilmu Hukum
# 78           Hukum         1                    Ilmu Hukum
# 79           Hukum         1                    Ilmu Hukum
# 80           Hukum         1                    Ilmu Hukum
# 81           Hukum         1                    Ilmu Hukum
# 82           Hukum         1                    Ilmu Hukum
# 83           Hukum         1                    Ilmu Hukum
# 84           Hukum         1                    Ilmu Hukum
# 85           Hukum         1                    Ilmu Hukum
# 86           Hukum         1                    Ilmu Hukum
# 87           Hukum         1                    Ilmu Hukum
# 88           Hukum         1                    Ilmu Hukum
# 89           Hukum         1                    Ilmu Hukum
# 90           Hukum         1                    Ilmu Hukum
# 91           Hukum         1                    Ilmu Hukum
# 92           Hukum         1                    Ilmu Hukum
# 93           Hukum         1                    Ilmu Hukum
# 94           Hukum         1                    Ilmu Hukum
# 95           Hukum         1                    Ilmu Hukum
# 96           Hukum         1                    Ilmu Hukum
# 97           Hukum         1                    Ilmu Hukum
# 98           Hukum         1                    Ilmu Hukum
# 99           Hukum         1                    Ilmu Hukum
# 100          Hukum         1                    Ilmu Hukum
# 101          Hukum         1                    Ilmu Hukum
# 102          Hukum         1                    Ilmu Hukum
# 103          Hukum         1                    Ilmu Hukum
# 104          Hukum         1                    Ilmu Hukum
# 105          Hukum         1                    Ilmu Hukum
# 106          Hukum         1                    Ilmu Hukum
# 107          Hukum         1                    Ilmu Hukum
# 108          Hukum         1                    Ilmu Hukum
# 109          Hukum         1                    Ilmu Hukum
# 110          Hukum         1                    Ilmu Hukum
# 111          Hukum         1                    Ilmu Hukum
# 112          Hukum         1                    Ilmu Hukum
# 113          Hukum         1                    Ilmu Hukum
# 114          Hukum         1                    Ilmu Hukum
# 115          Hukum         1                    Ilmu Hukum
# 116          Hukum         1                    Ilmu Hukum
# 117          Hukum         1                    Ilmu Hukum
# 118          Hukum         1                    Ilmu Hukum
# 119          Hukum         1                    Ilmu Hukum
# 120          Hukum         1                    Ilmu Hukum
# 121          Hukum         1                    Ilmu Hukum
# 122          Hukum         1                    Ilmu Hukum
# 123          Hukum         1                    Ilmu Hukum
# 124          Hukum         1                    Ilmu Hukum
# 125          Hukum         1                    Ilmu Hukum
# 126          Hukum         1                    Ilmu Hukum
# 127          Hukum         1                    Ilmu Hukum
# 128          Hukum         1                    Ilmu Hukum
# 129          Hukum         1                    Ilmu Hukum
# 130          Hukum         1                    Ilmu Hukum
# 131          Hukum         1                    Ilmu Hukum
# 132          Hukum         1                    Ilmu Hukum
# 133          Hukum         1                    Ilmu Hukum
# 134          Hukum         1                    Ilmu Hukum
# 135          Hukum         1                    Ilmu Hukum
# 136          Hukum         1                    Ilmu Hukum
# 137          Hukum         1                    Ilmu Hukum
# 138          Hukum         1                    Ilmu Hukum
# 139          Hukum         1                    Ilmu Hukum
# 140          Hukum         1                    Ilmu Hukum
# 141          Hukum         1                    Ilmu Hukum
# 142          Hukum         1                    Ilmu Hukum
# 143          Hukum         1                    Ilmu Hukum
# 144          Hukum         1                    Ilmu Hukum
# 145          Hukum         1                    Ilmu Hukum
# 146          Hukum         1                    Ilmu Hukum
# 147          Hukum         1                    Ilmu Hukum
# 148          Hukum         1                    Ilmu Hukum
# 149          Hukum         1                    Ilmu Hukum
# 150          Hukum         1                    Ilmu Hukum
# 151          Hukum         1                    Ilmu Hukum
# 152          Hukum         1                    Ilmu Hukum
# 153          Hukum         1                    Ilmu Hukum
# 154          Hukum         1                    Ilmu Hukum
# 155          Hukum         1                    Ilmu Hukum
# 156          Hukum         1                    Ilmu Hukum
# 157          Hukum         1                    Ilmu Hukum
# 158          Hukum         1                    Ilmu Hukum
# 159          Hukum         1                    Ilmu Hukum
# 160          Hukum         1                    Ilmu Hukum
# 161          Hukum         1                    Ilmu Hukum
# 162          Hukum         1                    Ilmu Hukum
# 163          Hukum         1                    Ilmu Hukum
# 164          Hukum         1                    Ilmu Hukum
# 165          Hukum         1                    Ilmu Hukum
# 166          Hukum         1                    Ilmu Hukum
# 167          Hukum         1                    Ilmu Hukum
# 168          Hukum         1                    Ilmu Hukum
# 169          Hukum         1                    Ilmu Hukum
# 170          Hukum         1                    Ilmu Hukum
# 171          Hukum         1                    Ilmu Hukum
# 172          Hukum         1                    Ilmu Hukum
# 173          Hukum         1                    Ilmu Hukum
# 174          Hukum         1                    Ilmu Hukum
# 175          Hukum         1                    Ilmu Hukum
# 176          Hukum         1                    Ilmu Hukum
# 177          Hukum         1                    Ilmu Hukum
# 178          Hukum         1                    Ilmu Hukum
# 179          Hukum         1                    Ilmu Hukum
# 180          Hukum         1                    Ilmu Hukum
# 181          Hukum         1                    Ilmu Hukum
# 182          Hukum         1                    Ilmu Hukum
# 183          Hukum         1                    Ilmu Hukum
# 184          Hukum         1                    Ilmu Hukum
# 185          Hukum         1                    Ilmu Hukum
# 186          Hukum         1                    Ilmu Hukum
# 187          Hukum         1                    Ilmu Hukum
# 188          Hukum         1                    Ilmu Hukum
# 189          Hukum         1                    Ilmu Hukum
# 190          Hukum         1                    Ilmu Hukum
# 191          Hukum         1                    Ilmu Hukum
# 192          Hukum         1                    Ilmu Hukum
# 193          Hukum         1                    Ilmu Hukum
# 194          Hukum         1                    Ilmu Hukum
# 195          Hukum         1                    Ilmu Hukum
# 196          Hukum         1                    Ilmu Hukum
# 197          Hukum         1                    Ilmu Hukum
# 198          Hukum         1                    Ilmu Hukum
# 199          Hukum         1                    Ilmu Hukum
# 200          Hukum         1                    Ilmu Hukum
# 201          Hukum         1                    Ilmu Hukum
# 202          Hukum         1                    Ilmu Hukum
# 203          Hukum         1                    Ilmu Hukum
# 204          Hukum         1                    Ilmu Hukum
# 205          Hukum         1                    Ilmu Hukum
# 206          Hukum         1                    Ilmu Hukum
# 207          Hukum         1                    Ilmu Hukum
# 208          Hukum         1                    Ilmu Hukum
# 209          Hukum         1                    Ilmu Hukum
# 210          Hukum         1                    Ilmu Hukum
# 211          Hukum         1                    Ilmu Hukum
# 212          Hukum         1                    Ilmu Hukum
# 213          Hukum         1                    Ilmu Hukum
# 214          Hukum         1                    Ilmu Hukum
# 215          Hukum         1                    Ilmu Hukum
# 216          Hukum         1                    Ilmu Hukum
# 217          Hukum         1                    Ilmu Hukum
# 218          Hukum         1                    Ilmu Hukum
# 219          Hukum         1                    Ilmu Hukum
# 220          Hukum         1                    Ilmu Hukum
# 221          Hukum         1                    Ilmu Hukum
# 222          Hukum         1                    Ilmu Hukum
# 223          Hukum         1                    Ilmu Hukum
# 224          Hukum         1                    Ilmu Hukum
# 225          Hukum         1                    Ilmu Hukum
# 226          Hukum         1                    Ilmu Hukum
# 227          Hukum         1                    Ilmu Hukum
# 228          Hukum         1                    Ilmu Hukum
# 229          Hukum         1                    Ilmu Hukum
# 230          Hukum         1                    Ilmu Hukum
# 231          Hukum         1                    Ilmu Hukum
# 232          Hukum         1                    Ilmu Hukum
# 233          Hukum         1                    Ilmu Hukum
# 234          Hukum         1                    Ilmu Hukum
# 235          Hukum         1                    Ilmu Hukum
# 236          Hukum         1                    Ilmu Hukum
# 237          Hukum         1                    Ilmu Hukum
# 238          Hukum         1                    Ilmu Hukum
# 239          Hukum         1                    Ilmu Hukum
# 240          Hukum         1                    Ilmu Hukum
# 241          Hukum         1                    Ilmu Hukum
# 242          Hukum         1                    Ilmu Hukum
# 243          Hukum         1                    Ilmu Hukum
# 244          Hukum         1                    Ilmu Hukum
# 245          Hukum         1                    Ilmu Hukum
# 246          Hukum         1                    Ilmu Hukum
# 247          Hukum         1                    Ilmu Hukum
# 248          Hukum         1                    Ilmu Hukum
# 249          Hukum         1                    Ilmu Hukum
# 250          Hukum         1                    Ilmu Hukum
# 251          Hukum         1                    Ilmu Hukum
# 252          Hukum         1                    Ilmu Hukum
# 253          Hukum         1                    Ilmu Hukum
# 254          Hukum         1                    Ilmu Hukum
# 255          Hukum         1                    Ilmu Hukum
# 256          Hukum         1                    Ilmu Hukum
# 257          Hukum         1                    Ilmu Hukum
# 258          Hukum         1                    Ilmu Hukum
# 259          Hukum         1                    Ilmu Hukum
# 260          Hukum         1                    Ilmu Hukum
# 261          Hukum         1                    Ilmu Hukum
# 262          Hukum         1                    Ilmu Hukum
# 263          Hukum         1                    Ilmu Hukum
# 264          Hukum         1                    Ilmu Hukum
# 265          Hukum         1                    Ilmu Hukum
# 266          Hukum         1                    Ilmu Hukum
# 267          Hukum         1                    Ilmu Hukum
# 268          Hukum         1                    Ilmu Hukum
# 269          Hukum         1                    Ilmu Hukum
# 270          Hukum         1                    Ilmu Hukum
# 271          Hukum         1                    Ilmu Hukum
# 272          Hukum         1                    Ilmu Hukum
# 273          Hukum         1                    Ilmu Hukum
# 274          Hukum         1                    Ilmu Hukum
# 275          Hukum         1                    Ilmu Hukum
# 276          Hukum         1                    Ilmu Hukum
# 277          Hukum         1                    Ilmu Hukum
# 278          Hukum         1                    Ilmu Hukum
# 279          Hukum         1                    Ilmu Hukum
# 280          Hukum         1                    Ilmu Hukum
# 281          Hukum         1                    Ilmu Hukum
# 282          Hukum         1                    Ilmu Hukum
# 283          Hukum         1                    Ilmu Hukum
# 284          Hukum         1                    Ilmu Hukum
# 285          Hukum         1                    Ilmu Hukum
# 286          Hukum         1                    Ilmu Hukum
# 287          Hukum         1                    Ilmu Hukum
# 288          Hukum         1                    Ilmu Hukum
# 289          Hukum         1                    Ilmu Hukum
# 290          Hukum         1                    Ilmu Hukum
# 291          Hukum         1                    Ilmu Hukum
# 292          Hukum         1                    Ilmu Hukum
# 293          Hukum         1                    Ilmu Hukum
# 294          Hukum         1                    Ilmu Hukum
# 295          Hukum         1                    Ilmu Hukum
# 296          Hukum         1                    Ilmu Hukum
# 297          Hukum         1                    Ilmu Hukum
# 298          Hukum         1                    Ilmu Hukum
# 299          Hukum         1                    Ilmu Hukum
# 300          Hukum         1                    Ilmu Hukum
# 301          Hukum         1                    Ilmu Hukum
# 302          Hukum         1                    Ilmu Hukum
# 303          Hukum         1                    Ilmu Hukum
# 304          Hukum         1                    Ilmu Hukum
# 305          Hukum         1                    Ilmu Hukum
# 306          Hukum         1                    Ilmu Hukum
# 307          Hukum         1                    Ilmu Hukum
# 308          Hukum         1                    Ilmu Hukum
# 309          Hukum         1                    Ilmu Hukum
# 310          Hukum         1                    Ilmu Hukum
# 311          Hukum         1                    Ilmu Hukum
# 312          Hukum         1                    Ilmu Hukum
# 313          Hukum         1                    Ilmu Hukum
# 314          Hukum         1                    Ilmu Hukum
# 315          Hukum         1                    Ilmu Hukum
# 316          Hukum         1                    Ilmu Hukum
# 317          Hukum         1                    Ilmu Hukum
# 318          Hukum         1                    Ilmu Hukum
# 319          Hukum         1                    Ilmu Hukum
# 320          Hukum         1                    Ilmu Hukum
# 321          Hukum         1                    Ilmu Hukum
# 322          Hukum         1                    Ilmu Hukum
# 323          Hukum         1                    Ilmu Hukum
# 324          Hukum         1                    Ilmu Hukum
# 325          Hukum         1                    Ilmu Hukum
# 326          Hukum         1                    Ilmu Hukum
# 327          Hukum         1                    Ilmu Hukum
# 328          Hukum         1                    Ilmu Hukum
# 329          Hukum         1                    Ilmu Hukum
# 330          Hukum         1                    Ilmu Hukum
# 331          Hukum         1                    Ilmu Hukum
# 332          Hukum         1                    Ilmu Hukum
# 333          Hukum         1                    Ilmu Hukum
# 334          Hukum         1                    Ilmu Hukum
# 335          Hukum         1                    Ilmu Hukum
# 336          Hukum         1                    Ilmu Hukum
# 337          Hukum         1                    Ilmu Hukum
# 338          Hukum         1                    Ilmu Hukum
# 339          Hukum         1                    Ilmu Hukum
# 340          Hukum         1                    Ilmu Hukum
# 341          Hukum         1                    Ilmu Hukum
# 342          Hukum         1                    Ilmu Hukum
# 343          Hukum         1                    Ilmu Hukum
# 344          Hukum         1                    Ilmu Hukum
# 345          Hukum         1                    Ilmu Hukum
# 346          Hukum         1                    Ilmu Hukum
# 347          Hukum         1                    Ilmu Hukum
# 348          Hukum         1                    Ilmu Hukum
# 349          Hukum         1                    Ilmu Hukum
# 350          Hukum         1                    Ilmu Hukum
# 351          Hukum         1                    Ilmu Hukum
# 352          Hukum         1                    Ilmu Hukum
# 353          Hukum         1                    Ilmu Hukum
# 354          Hukum         1                    Ilmu Hukum
# 355          Hukum         1                    Ilmu Hukum
# 356          Hukum         1                    Ilmu Hukum
# 357          Hukum         1                    Ilmu Hukum
# 358          Hukum         1                    Ilmu Hukum
# 359          Hukum         1                    Ilmu Hukum
# 360          Hukum         1                    Ilmu Hukum
# 361          Hukum         1                    Ilmu Hukum
# 362          Hukum         1                    Ilmu Hukum
# 363          Hukum         1                    Ilmu Hukum
# 364          Hukum         1                    Ilmu Hukum
# 365          Hukum         1                    Ilmu Hukum
# 366          Hukum         1                    Ilmu Hukum
# 367          Hukum         1                    Ilmu Hukum
# 368          Hukum         1                    Ilmu Hukum
# 369          Hukum         1                    Ilmu Hukum
# 370          Hukum         1                    Ilmu Hukum
# 371          Hukum         1                    Ilmu Hukum
# 372          Hukum         1                    Ilmu Hukum
# 373          Hukum         1                    Ilmu Hukum
# 374          Hukum         1                    Ilmu Hukum
# 375          Hukum         1                    Ilmu Hukum
# 376          Hukum         1                    Ilmu Hukum
# 377          Hukum         1                    Ilmu Hukum
# 378          Hukum         1                    Ilmu Hukum
# 379          Hukum         1                    Ilmu Hukum
# 380          Hukum         1                    Ilmu Hukum
# 381          Hukum         1                    Ilmu Hukum
# 382          Hukum         1                    Ilmu Hukum
# 383          Hukum         1                    Ilmu Hukum
# 384          Hukum         1                    Ilmu Hukum
# 385          Hukum         1                    Ilmu Hukum
# 386          Hukum         1                    Ilmu Hukum
# 387          Hukum         1                    Ilmu Hukum
# 388          Hukum         1                    Ilmu Hukum
# 389          Hukum         1                    Ilmu Hukum
# 390          Hukum         1                    Ilmu Hukum
# 391          Hukum         1                    Ilmu Hukum
# 392          Hukum         1                    Ilmu Hukum
# 393          Hukum         1                    Ilmu Hukum
# 394          Hukum         1                    Ilmu Hukum
# 395          Hukum         1                    Ilmu Hukum
# 396          Hukum         1                    Ilmu Hukum
# 397          Hukum         1                    Ilmu Hukum
# 398          Hukum         1                    Ilmu Hukum
# 399          Hukum         1                    Ilmu Hukum
# 400          Hukum         1                    Ilmu Hukum
# 401          Hukum         1                    Ilmu Hukum
# 402          Hukum         1                    Ilmu Hukum
# 403          Hukum         1                    Ilmu Hukum
# 404          Hukum         1                    Ilmu Hukum
# 405          Hukum         1                    Ilmu Hukum
# 406          Hukum         1                    Ilmu Hukum
# 407          Hukum         1                    Ilmu Hukum
# 408          Hukum         1                    Ilmu Hukum
# 409          Hukum         1                    Ilmu Hukum
# 410          Hukum         1                    Ilmu Hukum
# 411          Hukum         1                    Ilmu Hukum
# 412          Hukum         1                    Ilmu Hukum
# 413          Hukum         1                    Ilmu Hukum
# 414          Hukum         1                    Ilmu Hukum
# 415          Hukum         1                    Ilmu Hukum
# 416          Hukum         1                    Ilmu Hukum
# 417          Hukum         1                    Ilmu Hukum
# 418          Hukum         1                    Ilmu Hukum
# 419          Hukum         1                    Ilmu Hukum
# 420          Hukum         1                    Ilmu Hukum
# 421          Hukum         1                    Ilmu Hukum
# 422          Hukum         1                    Ilmu Hukum
# 423          Hukum         1                    Ilmu Hukum
# 424          Hukum         1                    Ilmu Hukum
# 425          Hukum         1                    Ilmu Hukum
# 426          Hukum         1                    Ilmu Hukum
# 427          Hukum         1                    Ilmu Hukum
# 428          Hukum         1                    Ilmu Hukum
# 429          Hukum         1                    Ilmu Hukum
# 430          Hukum         1                    Ilmu Hukum
# 431          Hukum         1                    Ilmu Hukum
# 432          Hukum         1                    Ilmu Hukum
# 433          Hukum         1                    Ilmu Hukum
# 434          Hukum         1                    Ilmu Hukum
# 435          Hukum         1                    Ilmu Hukum
# 436          Hukum         1                    Ilmu Hukum
# 437          Hukum         1                    Ilmu Hukum
# 438          Hukum         1                    Ilmu Hukum
# 439          Hukum         1                    Ilmu Hukum
# 440          Hukum         1                    Ilmu Hukum
# 441          Hukum         1                    Ilmu Hukum
# 442          Hukum         1                    Ilmu Hukum
# 443          Hukum         1                    Ilmu Hukum
# 444          Hukum         1                    Ilmu Hukum
# 445          Hukum         1                    Ilmu Hukum
# 446          Hukum         1                    Ilmu Hukum
# 447          Hukum         1                    Ilmu Hukum
# 448          Hukum         1                    Ilmu Hukum
# 449          Hukum         1                    Ilmu Hukum
# 450          Hukum         1                    Ilmu Hukum
# 451          Hukum         1                    Ilmu Hukum
# 452          Hukum         1                    Ilmu Hukum
# 453          Hukum         1                    Ilmu Hukum
# 454          Hukum         1                    Ilmu Hukum
# 455          Hukum         1                    Ilmu Hukum
# 456          Hukum         1                    Ilmu Hukum
# 457          Hukum         1                    Ilmu Hukum
# 458          Hukum         1                    Ilmu Hukum
# 459          Hukum         1                    Ilmu Hukum
# 460          Hukum         1                    Ilmu Hukum
# 461          Hukum         1                    Ilmu Hukum
# 462          Hukum         1                    Ilmu Hukum
# 463          Hukum         1                    Ilmu Hukum
# 464          Hukum         1                    Ilmu Hukum
# 465          Hukum         1                    Ilmu Hukum
# 466          Hukum         1                    Ilmu Hukum
# 467          Hukum         1                    Ilmu Hukum
# 468          Hukum         1                    Ilmu Hukum
# 469          Hukum         1                    Ilmu Hukum
# 470          Hukum         1                    Ilmu Hukum
# 471          Hukum         1                    Ilmu Hukum
# 472          Hukum         1                    Ilmu Hukum
# 473          Hukum         1                    Ilmu Hukum
# 474          Hukum         1                    Ilmu Hukum
# 475          Hukum         1                    Ilmu Hukum
# 476          Hukum         1                    Ilmu Hukum
# 477          Hukum         1                    Ilmu Hukum
# 478          Hukum         1                    Ilmu Hukum
# 479          Hukum         1                    Ilmu Hukum
# 480          Hukum         1                    Ilmu Hukum
# 481          Hukum         1                    Ilmu Hukum
# 482          Hukum         1                    Ilmu Hukum
# 483          Hukum         1                    Ilmu Hukum
# 484          Hukum         1                    Ilmu Hukum
# 485          Hukum         1                    Ilmu Hukum
# 486          Hukum         1                    Ilmu Hukum
# 487          Hukum         1                    Ilmu Hukum
# 488          Hukum         1                    Ilmu Hukum
# 489          Hukum         1                    Ilmu Hukum
# 490          Hukum         1                    Ilmu Hukum
# 491          Hukum         1                    Ilmu Hukum
# 492          Hukum         1                    Ilmu Hukum
# 493          Hukum         1                    Ilmu Hukum
# 494          Hukum         1                    Ilmu Hukum
# 495          Hukum         1                    Ilmu Hukum
# 496          Hukum         1                    Ilmu Hukum
# 497          Hukum         1                    Ilmu Hukum
# 498          Hukum         1                    Ilmu Hukum
# 499          Hukum         1                    Ilmu Hukum
# 500          Hukum         1                    Ilmu Hukum
# 501          Hukum         1                    Ilmu Hukum
# 502          Hukum         1                    Ilmu Hukum
# 503          Hukum         1                    Ilmu Hukum
# 504          Hukum         1                    Ilmu Hukum
# 505          Hukum         1                    Ilmu Hukum
# 506          Hukum         1                    Ilmu Hukum
# 507          Hukum         1                    Ilmu Hukum
# 508          Hukum         1                    Ilmu Hukum
# 509          Hukum         1                    Ilmu Hukum
# 510          Hukum         1                    Ilmu Hukum
# 511          Hukum         1                    Ilmu Hukum
# 512          Hukum         1                    Ilmu Hukum
# 513          Hukum         1                    Ilmu Hukum
# 514          Hukum         1                    Ilmu Hukum
# 515          Hukum         1                    Ilmu Hukum
# 516          Hukum         1                    Ilmu Hukum
# 517          Hukum         1                    Ilmu Hukum
# 518          Hukum         1                    Ilmu Hukum
# 519          Hukum         1                    Ilmu Hukum
# 520          Hukum         1                    Ilmu Hukum
# 521          Hukum         1                    Ilmu Hukum
# 522          Hukum         1                    Ilmu Hukum
# 523          Hukum         1                    Ilmu Hukum
# 524          Hukum         1                    Ilmu Hukum
# 525          Hukum         1                    Ilmu Hukum
# 526          Hukum         1                    Ilmu Hukum
# 527          Hukum         1                    Ilmu Hukum
# 528          Hukum         1                    Ilmu Hukum
# 529          Hukum         1                    Ilmu Hukum
# 530          Hukum         1                    Ilmu Hukum
# 531          Hukum         1                    Ilmu Hukum
# 532          Hukum         1                    Ilmu Hukum
# 533          Hukum         1                    Ilmu Hukum
# 534          Hukum         1                    Ilmu Hukum
# 535          Hukum         1                    Ilmu Hukum
# 536          Hukum         1                    Ilmu Hukum
# 537          Hukum         1                    Ilmu Hukum
# 538          Hukum         1                    Ilmu Hukum
# 539          Hukum         1                    Ilmu Hukum
# 540          Hukum         1                    Ilmu Hukum
# 541          Hukum         1                    Ilmu Hukum
# 542          Hukum         1                    Ilmu Hukum
# 543          Hukum         1                    Ilmu Hukum
# 544          Hukum         1                    Ilmu Hukum
# 545          Hukum         1                    Ilmu Hukum
# 546          Hukum         1                    Ilmu Hukum
# 547          Hukum         1                    Ilmu Hukum
# 548          Hukum         1                    Ilmu Hukum
# 549          Hukum         1                    Ilmu Hukum
# 550          Hukum         1                    Ilmu Hukum
# 551          Hukum         1                    Ilmu Hukum
# 552          Hukum         1                    Ilmu Hukum
# 553          Hukum         1                    Ilmu Hukum
# 554          Hukum         1                    Ilmu Hukum
# 555          Hukum         1                    Ilmu Hukum
# 556          Hukum         1                    Ilmu Hukum
# 557          Hukum         1                    Ilmu Hukum
# 558          Hukum         1                    Ilmu Hukum
# 559          Hukum         1                    Ilmu Hukum
# 560          Hukum         1                    Ilmu Hukum
# 561          Hukum         1                    Ilmu Hukum
# 562          Hukum         1                    Ilmu Hukum
# 563          Hukum         1                    Ilmu Hukum
# 564          Hukum         1                    Ilmu Hukum
# 565          Hukum         1                    Ilmu Hukum
# 566          Hukum         1                    Ilmu Hukum
# 567          Hukum         1                    Ilmu Hukum
# 568          Hukum         1                    Ilmu Hukum
# 569          Hukum         1                    Ilmu Hukum
# 570          Hukum         1                    Ilmu Hukum
# 571          Hukum         1                    Ilmu Hukum
# 572          Hukum         1                    Ilmu Hukum
# 573          Hukum         1                    Ilmu Hukum
# 574          Hukum         1                    Ilmu Hukum
# 575          Hukum         1                    Ilmu Hukum
# 576          Hukum         1                    Ilmu Hukum
# 577          Hukum         1                    Ilmu Hukum
# 578          Hukum         1                    Ilmu Hukum
# 579          Hukum         1                    Ilmu Hukum
# 580          Hukum         1                    Ilmu Hukum
# 581          Hukum         1                    Ilmu Hukum
# 582          Hukum         1                    Ilmu Hukum
# 583          Hukum         1                    Ilmu Hukum
# 584          Hukum         1                    Ilmu Hukum
# 585          Hukum         1                    Ilmu Hukum
# 586          Hukum         1                    Ilmu Hukum
# 587          Hukum         1                    Ilmu Hukum
# 588          Hukum         1                    Ilmu Hukum
# 589          Hukum         1                    Ilmu Hukum
# 590          Hukum         1                    Ilmu Hukum
# 591          Hukum         1                    Ilmu Hukum
# 592          Hukum         1                    Ilmu Hukum
# 593          Hukum         1                    Ilmu Hukum
# 594          Hukum         1                    Ilmu Hukum
# 595          Hukum         1                    Ilmu Hukum
# 596          Hukum         1                    Ilmu Hukum
# 597          Hukum         1                    Ilmu Hukum
# 598          Hukum         1                    Ilmu Hukum
# 599          Hukum         1                    Ilmu Hukum
# 600          Hukum         1                    Ilmu Hukum
# 601          Hukum         1                    Ilmu Hukum
# 602          Hukum         1                    Ilmu Hukum
# 603          Hukum         1                    Ilmu Hukum
# 604          Hukum         1                    Ilmu Hukum
# 605          Hukum         1                    Ilmu Hukum
# 606          Hukum         1                    Ilmu Hukum
# 607          Hukum         1                    Ilmu Hukum
# 608          Hukum         1                    Ilmu Hukum
# 609          Hukum         1                    Ilmu Hukum
# 610          Hukum         1                    Ilmu Hukum
# 611          Hukum         1                    Ilmu Hukum
# 612          Hukum         1                    Ilmu Hukum
# 613          Hukum         1                    Ilmu Hukum
# 614          Hukum         1                    Ilmu Hukum
# 615          Hukum         1                    Ilmu Hukum
# 616          Hukum         1                    Ilmu Hukum
# 617          Hukum         1                    Ilmu Hukum
# 618          Hukum         1                    Ilmu Hukum
# 619          Hukum         1                    Ilmu Hukum
# 620          Hukum         1                    Ilmu Hukum
# 621          Hukum         1                    Ilmu Hukum
# 622          Hukum         1                    Ilmu Hukum
# 623          Hukum         1                    Ilmu Hukum
# 624          Hukum         1                    Ilmu Hukum
# 625          Hukum         1                    Ilmu Hukum
# 626          Hukum         1                    Ilmu Hukum
# 627          Hukum         1                    Ilmu Hukum
# 628          Hukum         1                    Ilmu Hukum
# 629          Hukum         1                    Ilmu Hukum
# 630          Hukum         1                    Ilmu Hukum
# 631          Hukum         1                    Ilmu Hukum
# 632          Hukum         1                    Ilmu Hukum
# 633          Hukum         1                    Ilmu Hukum
# 634          Hukum         1                    Ilmu Hukum
# 635          Hukum         1                    Ilmu Hukum
# 636          Hukum         1                    Ilmu Hukum
# 637          Hukum         1                    Ilmu Hukum
# 638          Hukum         1                    Ilmu Hukum
# 639          Hukum         1                    Ilmu Hukum
# 640          Hukum         1                    Ilmu Hukum
# 641          Hukum         1                    Ilmu Hukum
# 642          Hukum         1                    Ilmu Hukum
# 643          Hukum         1                    Ilmu Hukum
# 644          Hukum         1                    Ilmu Hukum
# 645          Hukum         1                    Ilmu Hukum
# 646          Hukum         1                    Ilmu Hukum
# 647          Hukum         1                    Ilmu Hukum
# 648          Hukum         1                    Ilmu Hukum
# 649          Hukum         1                    Ilmu Hukum
# 650          Hukum         1                    Ilmu Hukum
# 651          Hukum         1                    Ilmu Hukum
# 652          Hukum         1                    Ilmu Hukum
# 653          Hukum         1                    Ilmu Hukum
# 654          Hukum         1                    Ilmu Hukum
# 655          Hukum         1                    Ilmu Hukum
# 656          Hukum         1                    Ilmu Hukum
# 657          Hukum         1                    Ilmu Hukum
# 658          Hukum         1                    Ilmu Hukum
# 659          Hukum         1                    Ilmu Hukum
# 660          Hukum         1                    Ilmu Hukum
# 661          Hukum         1                    Ilmu Hukum
# 662          Hukum         1                    Ilmu Hukum
# 663          Hukum         1                    Ilmu Hukum
# 664          Hukum         1                    Ilmu Hukum
# 665          Hukum         1                    Ilmu Hukum
# 666          Hukum         1                    Ilmu Hukum
# 667          Hukum         1                    Ilmu Hukum
# 668          Hukum         1                    Ilmu Hukum
# 669          Hukum         1                    Ilmu Hukum
# 670          Hukum         1                    Ilmu Hukum
# 671          Hukum         1                    Ilmu Hukum
# 672          Hukum         1                    Ilmu Hukum
# 673          Hukum         1                    Ilmu Hukum
# 674          Hukum         1                    Ilmu Hukum
# 675          Hukum         1                    Ilmu Hukum
# 676          Hukum         1                    Ilmu Hukum
# 677          Hukum         1                    Ilmu Hukum
# 678          Hukum         1                    Ilmu Hukum
# 679          Hukum         1                    Ilmu Hukum
# 680          Hukum         1                    Ilmu Hukum
# 681          Hukum         1                    Ilmu Hukum
# 682          Hukum         1                    Ilmu Hukum
# 683          Hukum         1                    Ilmu Hukum
# 684          Hukum         1                    Ilmu Hukum
# 685          Hukum         1                    Ilmu Hukum
# 686          Hukum         1                    Ilmu Hukum
# 687          Hukum         1                    Ilmu Hukum
# 688          Hukum         1                    Ilmu Hukum
# 689          Hukum         1                    Ilmu Hukum
# 690          Hukum         1                    Ilmu Hukum
# 691          Hukum         1                    Ilmu Hukum
# 692          Hukum         1                    Ilmu Hukum
# 693          Hukum         1                    Ilmu Hukum
# 694          Hukum         1                    Ilmu Hukum
# 695          Hukum         1                    Ilmu Hukum
# 696          Hukum         1                    Ilmu Hukum
# 697          Hukum         1                    Ilmu Hukum
# 698          Hukum         1                    Ilmu Hukum
# 699          Hukum         1                    Ilmu Hukum
# 700          Hukum         1                    Ilmu Hukum
# 701          Hukum         1                    Ilmu Hukum
# 702          Hukum         1                    Ilmu Hukum
# 703          Hukum         1                    Ilmu Hukum
# 704          Hukum         1                    Ilmu Hukum
# 705          Hukum         1                    Ilmu Hukum
# 706          Hukum         1                    Ilmu Hukum
# 707          Hukum         1                    Ilmu Hukum
# 708          Hukum         1                    Ilmu Hukum
# 709          Hukum         1                    Ilmu Hukum
# 710          Hukum         1                    Ilmu Hukum
# 711          Hukum         1                    Ilmu Hukum
# 712          Hukum         1                    Ilmu Hukum
# 713          Hukum         1                    Ilmu Hukum
# 714          Hukum         1                    Ilmu Hukum
# 715          Hukum         1                    Ilmu Hukum
# 716          Hukum         1                    Ilmu Hukum
# 717          Hukum         1                    Ilmu Hukum
# 718          Hukum         1                    Ilmu Hukum
# 719          Hukum         1                    Ilmu Hukum
# 720          Hukum         1                    Ilmu Hukum
# 721          Hukum         1                    Ilmu Hukum
# 722          Hukum         1                    Ilmu Hukum
# 723          Hukum         1                    Ilmu Hukum
# 724          Hukum         1                    Ilmu Hukum
# 725          Hukum         1                    Ilmu Hukum
# 726          Hukum         1                    Ilmu Hukum
# 727          Hukum         1                    Ilmu Hukum
# 728          Hukum         1                    Ilmu Hukum
# 729          Hukum         1                    Ilmu Hukum
# 730          Hukum         1                    Ilmu Hukum
# 731          Hukum         1                    Ilmu Hukum
# 732          Hukum         1                    Ilmu Hukum
# 733          Hukum         1                    Ilmu Hukum
# 734          Hukum         1                    Ilmu Hukum
# 735          Hukum         1                    Ilmu Hukum
# 736          Hukum         1                    Ilmu Hukum
# 737          Hukum         1                    Ilmu Hukum
# 738          Hukum         1                    Ilmu Hukum
# 739          Hukum         1                    Ilmu Hukum
# 740          Hukum         1                    Ilmu Hukum
# 741          Hukum         1                    Ilmu Hukum
# 742          Hukum         1                    Ilmu Hukum
# 743          Hukum         1                    Ilmu Hukum
# 744          Hukum         1                    Ilmu Hukum
# 745          Hukum         1                    Ilmu Hukum
# 746          Hukum         1                    Ilmu Hukum
# 747          Hukum         1                    Ilmu Hukum
# 748          Hukum         1                    Ilmu Hukum
# 749          Hukum         1                    Ilmu Hukum
# 750          Hukum         1                    Ilmu Hukum
# 751          Hukum         1                    Ilmu Hukum
# 752          Hukum         1                    Ilmu Hukum
# 753          Hukum         1                    Ilmu Hukum
# 754          Hukum         1                    Ilmu Hukum
# 755          Hukum         1                    Ilmu Hukum
# 756          Hukum         1                    Ilmu Hukum
# 757          Hukum         1                    Ilmu Hukum
# 758          Hukum         1                    Ilmu Hukum
# 759          Hukum         1                    Ilmu Hukum
# 760          Hukum         1                    Ilmu Hukum
# 761          Hukum         1                    Ilmu Hukum
# 762          Hukum         1                    Ilmu Hukum
# 763          Hukum         1                    Ilmu Hukum
# 764          Hukum         1                    Ilmu Hukum
# 765          Hukum         1                    Ilmu Hukum
# 766          Hukum         1                    Ilmu Hukum
# 767          Hukum         1                    Ilmu Hukum
# 768          Hukum         1                    Ilmu Hukum
# 769          Hukum         1                    Ilmu Hukum
# 770          Hukum         1                    Ilmu Hukum
# 771          Hukum         1                    Ilmu Hukum
# ...
# 2332  The purpose of this study is to find out what ...
# 2333  Soybeans are an important commodity in Indones...
# 2334  Tobacco farmers of Madura become a price taker...
# 2335  FACTORS THAT AFFECT THE PRODUCTION OF TOBACCO ...
# 2336  Food is the most basic requirements to meet th...
# 2337  Since the operation of the bridge suramadu Mad...
# 2338  The amount of land is relatively fixed while t...
# 2339  he helplessness of tobacco farmers due to the ...
# 2340  ABSTRACT Potensial of Madura island as a natio...
# 2341  Long pepper (Piper retrofactum Vahl) is one of...
# 2342  ABSTRACT Melinjo (tree bearing edible leaves a...
# 2343  Foundation of Al-Falah Islamic Boarding School...
# 2344  This research aims to knowing the outpouring t...
# 2345  ABSTRACT This research was conducted In Gili I...
# 2346  ABSTRACT Gayam District as the largest of Madu...
# 2347  ABSTRACT Herb of Madura has a smell distinctiv...
# 2348  ABSTRACT Long peppers were the one of superior...
# 2349  ABSTRACT This research was doing in Kompol Vil...
# 2350  This reseach identifying the level of food ins...
# 2351  Onion is horticulture comodity with high deman...
# 2352  India is one of the export destination of Long...
# 2353  Long Pipermis kind of medicane plants have hig...
# 2354  Large uptake of Long pepper is about 9.5% of t...
# 2355  This study aims to describe the characteristic...
# 2356  This study conducted in Kalitengah Village Sug...
# 2357  ABSTRACK Sugar is one of the important nationa...
# 2358  ABSTRACT Long pepper is one of the existing pl...
# 2359  In 2010, the Indonesia government launched bac...
# 2360  ABSTRACT Corn is one of the most consumed food...
# 2361  Milkfish (chanos chanosis) is one of consumpti...
# 2362  ABSTRACT Increasing the number of residents af...
# 2363  ABSTRACT This study aims to know the patterns ...
# 2364  ABSTRACT This study aims to determine the char...
# 2365  This research aims to know the socio-economic ...
# 2366  Indonesia is an agrarian country where agricul...
# 2367  This research was conducted at Pondok Pesantre...
# 2368  Indonesia as a maritime country has potential ...
# 2369  Indonesia is the second country which produced...
# 2370  Palm oil the superior export commodity in Indo...
# 2371  This research to know the profile of activitie...
# 2372  This study conducted in Kompol Village Geger S...
# 2373  The objectives of this study are (1) to know t...
# 2374  Long peppers were the one of superior commodit...
# 2375  The aims of this research are (1) to observeth...
# 2376  Kapedi has the biggest number of populations o...
# 2377  Petis Konang was one of commodity which was mo...
# 2378  ABSTRACT This research to analyze the characte...
# 2379  Sub-district of Rubaru is the center of greatc...
# 2380  This study aims to determine factors are inclu...
# 2381  This research was conducted in Bangkalan distr...
# 2382  Cassava Chips Windu Agung is a processed produ...
# 2383  Food insecurity is a condition which individua...
# 2384  This study discusses the industrial sector is ...
# 2385  The island of Madura has great potential in th...
# 2386  The purpose of this research is to knowing the...
# 2387  This research find out the difference way of c...
# 2388  This research is located in Jrengik Village, J...
# 2389  The aims of the researchs were describe the ch...
# 2390  Indonesia as a agricultural country has a big ...
# 2391  Cooperation Undertaken by ASEAN, not only with...
# 2392  Soybean is one of the foodstuff in Indonesia w...
# 2393  Bangkalan regency has 18 regions which devided...
# 2394  UD Anugerah is a tofu industry which has limit...
# 2395  UD Sinar Jepara is one the furniture companies...
# 2396  The world corn price fluctuations will affect ...
# 2397  Banyuwangi is a one part of East Java who have...
# 2398  The vaname shrimp farmers in Kwanyar sub distr...
# 2399  One of the micro and medium enterprises (UMKM)...
# 2400  This study aimed to analyze the structure, beh...
# 2401  Pati Regency has many tourist attraction of na...
# 2402  Coffee is a mainstay of plantation comodity wh...
# 2403  The purpose of this research is to know the so...
# 2404  One of the livestock products that play an imp...
# 2405  The potential of abundant seafood in Dharma Ta...
# 2406  Balanced scorecard concept introduces a cooper...
# 2407  Pepper is the king of spices that serve as a s...
# 2408  ABSTRACT The farmers in Kecamatan Kadur are st...
# 2409  The low price received by farmers in Bana Sare...
# 2410  This research was done in Paradila CVParengan ...
# 2411  Agriculture is a very important and strategic ...
# 2412  Southeast Asia Indonesia 4.84 corn productivit...
# 2413  ABSTRACT Thai Pepper (Cabai Rawit) Commodity i...
# 2414  The micro small and medium enterprises engaged...
# 2415  Changes in commodity prices cayenne cause trad...
# 2416  UD.Puspa Marina is one of the biggest processi...
# 2417  One of the agricultural sub-sector with the po...
# 2418  Pesona Batik Madura is one of the batik indust...
# 2419  One of UMKM in Sidoarjo Regency is UMKM Salted...
# 2420  Agro-tourism is a series of rural activities, ...
# 2421  This research was conducted in Taddan Village,...
# 2422  Hana Safitri. NIM. 140321100077. The level of ...
# 2423  Horticulture is a sub-sector of agricultural t...
# 2424  Maize production continues to increase, Lamong...
# 2425  Food in human needs is one of the most basic n...
# 2426  Beef cattle is one source of groceries that ar...
# 2427  Sampang Regency has a small island located in ...
# 2428  Pamekasan has many tourist attractions with th...
# 2429  Mojokerto is one of province in East Java whic...
# 2430  Countries all over the world have set certain ...
# 2431  Sampang district has many tourist attractions,...
# 2432  Muhammad Iqbal. 140321100039. Value Added Agro...
# 2433  Pamekasan is the center of the salt of 4 distr...
# 2434  Tuna is one of the mainstay of the fishery cat...
# 2435  Low price received by the farmer at Tanjung vi...
# 2436  The production and productivity level of cayen...
# 2437  This study discusses the food crop sub-sector....
# 2438  Mandangin island has the potensial of natural ...
# 2439  Diwek Sub District is one of the centers of ca...
# 2440  ABSTRACT Beef cattle is one set nationally com...
# 2441  Madurese cattle are known as germplasm that ar...
# 2442  Kolpajung Traditional Market is one of the big...
# 2443  Sumenep is one of district in Madura Island. S...
# 2444  The research was conducted in Bluto Village, B...
# 2445  This research was conducted in Pademawu Barat ...
# 2446  This study aimed to analyze the marketing acti...
# 2447  Camplong beach is one of the tourism into comm...
# 2448  This study aims to determine the characteristi...
# 2449  The purpose of this study is to know the chara...
# 2450  ABSTRACT: Organic farming techniques is one te...
# 2451  The cultural art that still strong and sothick...
# 2452  Mega Sulfia. 140321100016. Motivation And Perc...
# 2453  Beef Cattle is one of bussines field of husban...
# 2454  The purpose of this study was to determine the...
# 2455  Madura is one of the producers of beef cattle ...
# 2456  This research was conducted in Ecotourism Bang...
# 2457  Madura is one of the islands that has potentia...
# 2458  The reseach was conducted in Keleyan village, ...
# 2459  One of successful petis (condiment of fermente...
# 2460  Uncertainty or risk level of price for large c...
# 2461  This study aims to determine the classificatio...
# 2462  ABSTRACT Bangkalan is one of the districts in ...
# 2463  Red onion belongs to a group of unsubstituted ...
# 2464  The study was conducted in the City of Pamekas...
# 2465  The purpose of this study was to determine the...
# 2466  ABSTRACT Prambanan village is a village that h...
# 2467  The increase of corn demand in Indonesia, whic...
# 2468  Marketing strategy is a plan that is comprehen...
# 2469  Batik is a cultural symbol that has high selli...
# 2470  ABSTRACT Jaddih village is one of the villages...
# 2471  Tourism becomes one of the most important sect...
# 2472  Indonesia depends on agriculture sector. But s...
# 2473  The population of Mandangin society is very hi...
# 2474  The agricultural sector is the most important ...
# 2475  The increase in population and the development...
# 2476  ABSTRACT: The availability of abundant enough ...
# 2477                                                NaN
# 2478  Madura have huge potencies in exoctic fruits p...
# 2479  This study aims to analyze (1) the amount of i...
# 2480  Decree of the Minister of Agriculture No. 511 ...
# 2481  ABSTRACT The high level of rice consumption ha...
# 2482  ABSTRACT Salt production can be done in two wa...
# 2483  Rice Farming Insurance (Asuransi Usahatani Pad...
# 2484  ABSTRACT Indonesia has many types of animals t...
# 2485  Extension is the involvement of someone to com...
# 2486  One of Indonesia's rubber export destination c...
# 2487  Lembung Village is the largest salt producer c...
# 2488  Sugarcane farming in Bangkalan Regency has dec...
# 2489  Salt is a commodity that is needed to meet the...
# 2490  The amount of rice production in Tambak Sub-di...
# 2491  Woven fabric has the potential to contribute t...
# 2492  Horticulture is a driving subsector of develop...
# 2493  The existence of duck business will definitely...
# 2494  Intako Cooperative is a shopping tourism cente...
# 2495  ABSTRACT Demand for food such as beef which ha...
# 2496  Madura tobacco farmers are faced with various ...
# 2497  Banyuwangi is one of the largest districts in ...
# 2498  In accordance with Permentan number 25 of 2008...
# 2499  Sumenep is part of the district in Madura whic...
# 2500  Community Development is a method of including...
# 2501  Sub-regency of Rejoso is known as the center o...
# 2502  Wilangan District is one of the red onion area...
# 2503  One of the shrimp-producing coastal areas Vana...
# 2504  ABSTRACT Vilage-Owned Enterprise Menara Prakid...
# 2505  One of the plantation corps which capable to c...
# 2506  Maintenance of irrigation drain is one of the ...
# 2507  Indonesia as an agricultural country that have...
# 2508  Pineapple is one of the horticultural products...
# 2509  ABSTRACT Agricultural sector has the largest c...
# 2510  ABSTRAK In 2013 until 2018 sugarcane land in B...
# 2511  Madura is an island where the majority of the ...
# 2512  Maksalina Luthfa Hunaya. NIM 150321100015. Mea...
# 2513  Bangkalan Regency is the lowest salt producing...
# 2514  Weak bargaining power by farmers and fluctuati...
# 2515  The purpose of this study was to determine the...
# 2516  This study aims to analyze (1) the feasibility...
# 2517  Supply Chainis a network of companies that sim...
# 2518  Pakandangan Sangrah Village is one of the area...
# 2519  Organic rice has a higher price compared to no...
# 2520  ABSTRACT Japanese food business in Indonesia i...
# 2521  Pamekasan Regency is the second largest center...
# 2522  Japan is an export destination for Indonesian ...
# 2523  Marlean IKM, the coconut shell bag craft indus...
# 2524  Coffee is one type of plantation that has long...
# 2525  This study was conducted in Buket Backwoods, P...
# 2526  Salt needs continue to increase, but imports a...
# 2527  Indonesia as the second country of the longest...
# 2528  The number of PNS agricultural extension agent...
# 2529  Pati Regency is one of the cities that has man...
# 2530  Parang Ijo Waterfall Ecotourism in the village...
# 2531  ABSTRACT Landfill Buluh village is the only on...
# 2532  ABSTRACT The purpose of this study was to dete...
# 2533  ABSTRACT The research was conducted in Bluto V...
# 2534  Vaname shrimp is an introduced species that ha...
# 2535  The low price offered by traders in Banasare V...
# 2536  Low pricing and quality at every trader, resul...
# 2537  Broiler duck was a potential commodity in Burn...
# 2538  Kandangan Village, District Cerme is one of th...
# 2539  Humans are main factor for production that det...
# 2540  This study conducted in Pakandangan Village Bl...
# 2541  The domestic household industry is a food proc...
# 2542  ABSTRACT This research was conducted in Polaga...
# 2543  Banyusangkah's specialty salted fish products ...
# 2544  Sambeng Subdistrict is one of the corn product...
# 2545  Rizka Fadillah. NIM 150321100052. (Analysis In...
# 2546  This research was conducted in Gumirih Village...
# 2547  The food crop sub-sector consisting of rice, c...
# 2548  The agricultural sector is inseparable from th...
# 2549  Rice production in Sambeng Subdistrict, Lamong...
# 2550  ABSTRACT The village of Kakat Penjalin is a la...
# 2551  Bangkalan Regency is one of the tourist destin...
# 2552  UD. Aisyah Group grilled milk fish cake indust...
# 2553  Bangkalan is one of the most popular tourist d...
# 2554  Attachment to ministerial regulation of agricu...
# 2555  The main function / role of the environment is...
# 2556  Ngimbang District is one of the sub-districts ...
# 2557  The productivity of salt ponds in Lembung Vill...
# 2558  This study aims to describe the entrepreneuria...
# 2559  ADOPTION LEVEL OF MADURA-3 CORN INNOVATION IN ...
# 2560  Syahrul Makhosin. NIM: 150321100043. Factors A...
# 2561  ABSTRACT Syzygium aqueum is one type of fruit ...
# 2562  Increasing of population that continous to inc...
# 2563  Tinalan Urban Village is a Village located in ...
# 2564  A Fisherman supplies himself with a livelihood...
# 2565  ABSTRACT ix This study aims to analyze (1) the...
# 2566  ABSTRACT The number of tourists visiting the S...
# 2567  Corn is a strategic commodity in Indonesia. Ma...
# 2568                                                NaN
# 2569                                                NaN
# 2570                                                NaN
# 2571                                                NaN
# 2572                                                NaN
# 2573                                                NaN
# 2574                                                NaN
# 2575                                                NaN
# 2576                                                NaN
# 2577                                                NaN
# 2578                                                NaN
# 2579                                                NaN
# 2580                                                NaN
# 2581                                                NaN
# 2582                                                NaN
# 2583                                                NaN
# 2584                                                NaN
# 2585                                                NaN
# 2586                                                NaN
# 2587                                                NaN
# 2588                                                NaN
# 2589                                                NaN
# 2590                                                NaN
# 2591                                                NaN
# 2592                                                NaN
# 2593                                                NaN
# 2594                                                NaN
# 2595                                                NaN
# 2596                                                NaN
# 2597          I'ANATUS SHOFIYAH;160321100035;AGRIBISNIS
# 2598                                                NaN
# 2599                                                NaN
# 2600  Yusriansyah. 08.03.1.1.1.00005. Provision of W...
# 2601  ABSTRACT Iler (Coleus scutellarioides Linn. Be...
# 2602  Pakchoi (Brassica juncea L.). is one kind of a...
# 2603  Shallot is one commodity that is widely used v...
# 2604  Java long pepper (Piper retrofractum Vahl) is ...
# 2605  Planting Cuttings cayenne herbs directly on th...
# 2606  ABSTRACT Cabe herbs (Piper retrofractum Vahl) ...
