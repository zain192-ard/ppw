# %% [markdown]
# # Crawling Twiter

# %%
#@title Twitter Auth Token

twitter_auth_token = '089461130802eab657b4137d8ddfefdd93f35055'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Hit:1 https://dl.google.com/linux/chrome/deb stable InRelease
# Hit:2 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:3 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable InRelease
# Hit:4 https://dl.yarnpkg.com/debian stable InRelease
# Hit:5 https://packages.microsoft.com/repos/microsoft-ubuntu-noble-prod noble InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:8 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203).
# curl is already the newest version (8.5.0-2ubuntu10.6).
# gnupg is already the newest version (2.4.4-2ubuntu17.3).
# 0 upgraded, 0 newly installed, 0 to remove and 101 not upgraded.
# File '/etc/apt/keyrings/nodesource.gpg' exists. Overwrite? (y/N)
# gpg: signal Interrupt caught ... exiting
# ^C
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 https://packages.microsoft.com/repos/microsoft-ubuntu-noble-prod noble InRelease
# Hit:2 https://dl.google.com/linux/chrome/deb stable InRelease
# Hit:3 https://dl.yarnpkg.com/debian stable InRelease
# Hit:4 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable InRelease
# Hit:5 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:6 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Reading package lists... Done
# v22.17.0

# %%
filename = 'saham.csv'
search_keyword = 'saham lang:id'
limit = 1000

# Install missing dependencies for Playwright/Chromium
# !sudo apt-get install -y libatk1.0-0 libatk-bridge2.0-0 libgdk-pixbuf2.0-0 libgtk-3-0 libgbm-dev libxss1

# !npx --yes tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token} --delay 5
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libatk1.0-0t64' instead of 'libatk1.0-0'
# Note, selecting 'libatk-bridge2.0-0t64' instead of 'libatk-bridge2.0-0'
# Note, selecting 'libgtk-3-0t64' instead of 'libgtk-3-0'
# libatk1.0-0t64 is already the newest version (2.52.0-1build1).
# libatk-bridge2.0-0t64 is already the newest version (2.52.0-1build1).
# libgdk-pixbuf2.0-0 is already the newest version (2.40.2-3build2).
# libgtk-3-0t64 is already the newest version (3.24.41-4ubuntu1.3).
# libgbm-dev is already the newest version (25.0.7-0ubuntu0.24.04.2).
# libxss1 is already the newest version (1:1.2.3-1build3).
# 0 upgraded, 0 newly installed, 0 to remove and 101 not upgraded.
# Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2)
# Filling in keywords: saham lang:id
#
#  (3)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 19
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 39
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 59
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 79
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 98
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 114
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 129
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 143
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 153
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 163
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 173
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 185
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 196
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 206
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 215
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 223
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 231
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 240
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 249
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 258
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 265
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 272
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 279
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 285
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 291
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 296
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 316
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 322
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 327
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 333
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 339
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 345
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 351
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 357
#
# -- Scrolling... (1)
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 363
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 369
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 373
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 378
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 382
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 385
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 388
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 391
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 394
#
#
# Your tweets saved to: /workspaces/ppw/tugas/tweets-data/saham.csv
# Total tweets saved: 397
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@a78cf5da26a5806c252cd75375dabfe3"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@2e70a2885b5634bba26779f12b86579a"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@51ea6159299337c2a4a7e56b7fb9c419"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@6ac2811fbf50050f86b3c8540d1604be"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@fe5a164d54838859fd1a13b447fa5b9a"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# ^C

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)

# Check the length of the DataFrame
num_rows = len(df)
print(f"The number of rows in the DataFrame is: {num_rows}")
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1992917649479901509  Mon Nov 24 11:26:08 +0000 2025             663
# 1    1992363107331788973  Sat Nov 22 22:42:35 +0000 2025            1344
# 2    1995363539469705605  Mon Dec 01 05:25:14 +0000 2025             505
# 3    1993259031247700235  Tue Nov 25 10:02:40 +0000 2025             149
# 4    1993512148874752177  Wed Nov 26 02:48:28 +0000 2025             355
# ..                   ...                             ...             ...
# 392  1995367890955207049  Mon Dec 01 05:42:32 +0000 2025              47
# 393  1994647485466448183  Sat Nov 29 10:46:13 +0000 2025              12
# 394  1992124649040392657  Sat Nov 22 06:55:02 +0000 2025              22
# 395  1995741893670699469  Tue Dec 02 10:51:38 +0000 2025               6
# 396  1992548573159043255  Sun Nov 23 10:59:34 +0000 2025              99
#
#                                              full_text               id_str  \
# 0    screening awal gw kalau cari saham 1. Dari ami...  1992917649479901509
# 1    Rahasia Menyaring Saham Turnaround Multibagger...  1992363107331788973
# 2    Struktur IPO $RLCO M-ARA ARB 35% TM- No Waran ...  1995363539469705605
# 3    Shm! baru tau sekarang bisa lock saham pesan d...  1993259031247700235
# 4    Daftar pantauan Berdasarkan jenis Setup: 1. Tr...  1993512148874752177
# ..                                                 ...                  ...
# 392  Shm! Gess sorry oot aku anak rantau dari sumat...  1995367890955207049
# 393  @desmondwira Transaksi tgl 6 Oktober dilakukan...  1994719543063974277
# 394  Kejadian lagi Harus ada tindakan sanksi ke sek...  1992124649040392657
# 395                                   $BUVA bakal gini  1995808070304497949
# 396  Relate ga sama UU BUMN kemarin yg di protes ? ...  1992548573159043255
#
#                                            image_url in_reply_to_screen_name  \
# 0    https://pbs.twimg.com/media/G6hEBJ8akAA3vM1.jpg                     NaN
# 1    https://pbs.twimg.com/media/G6ZF94sbIAAfxyt.jpg                     NaN
# 2    https://pbs.twimg.com/media/G7Dy2IYa0AA-HRo.png                     NaN
# 3    https://pbs.twimg.com/media/G6l6hQ0bwAA7DQa.jpg                     NaN
# 4    https://pbs.twimg.com/media/G6pglCOaYAAcUl3.png                     NaN
# ..                                               ...                     ...
# 392                                              NaN                     NaN
# 393                                              NaN             desmondwira
# 394                                              NaN                     NaN
# 395                                              NaN               JudiSaham
# 396                                              NaN                     NaN
#
#     lang  location  quote_count  reply_count  retweet_count  \
# 0     in       NaN            0            2             63
# 1     in       NaN            8           15            286
# 2     in       NaN            2           13             74
# 3     in       NaN            9           49             23
# 4     in       NaN            2           12             35
# ..   ...       ...          ...          ...            ...
# 392   in       NaN            4           10              4
# 393   in       NaN            0            1              1
# 394   in       NaN            0            1              6
# 395   in       NaN            0            3              0
# 396   in       NaN            0           11             24
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/undefined/status/199291764947990...  1345898259445817345
# 1    https://x.com/undefined/status/199236310733178...  1509650609120718860
# 2    https://x.com/undefined/status/199536353946970...           1634788663
# 3    https://x.com/undefined/status/199325903124770...  1336580251493646343
# 4    https://x.com/undefined/status/199351214887475...  1305725907584286720
# ..                                                 ...                  ...
# 392  https://x.com/undefined/status/199536789095520...  1336580251493646343
# 393  https://x.com/undefined/status/199471954306397...             80564666
# 394  https://x.com/undefined/status/199212464904039...  1260798424393211904
# 395  https://x.com/undefined/status/199580807030449...  1294174592055967746
# 396  https://x.com/undefined/status/199254857315904...  1260798424393211904
#
#      username
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 392       NaN
# 393       NaN
# 394       NaN
# 395       NaN
# 396       NaN
#
# [397 rows x 15 columns]
# The number of rows in the DataFrame is: 397
