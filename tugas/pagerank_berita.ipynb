# %% [markdown]
# # Page Rank Berita

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from collections import deque  # Antrian (queue) yang efisien
import time
import sys
import pandas as pd

def build_pagerank_dataset(start_url, max_pages=50, delay=0.1):
    """
    Melakukan crawling multi-halaman untuk membangun edge list untuk PageRank.
    """
    
    pages_to_visit = deque([start_url])
    visited_pages = set()
    edge_list = []
    
    try:
        hostname = urlparse(start_url).hostname
        if not hostname:
            raise ValueError("Hostname tidak ditemukan. Pastikan URL diawali 'https://' atau 'http://'")
        base_hostname = hostname.replace('www.', '')
    except (ValueError, AttributeError) as e:
        print(f"Error: URL awal tidak valid -> '{start_url}'")
        print(f"Detail: {e}")
        return pd.DataFrame(columns=["Halaman Sumber", "Link Keluar (Internal)"]) 

    print(f"Memulai crawl dari: {start_url}")
    print(f"Domain target: {base_hostname}")
    print(f"Batas halaman: {max_pages}\n")

    IGNORED_EXTENSIONS = (
        '.png', '.jpg', '.jpeg', '.gif', '.svg', '.bmp', '.tiff', '.webp',
        '.pdf', '.doc', '.docx', '.xls', '.xlsx', '.ppt', '.pptx',
        '.zip', '.rar', '.gz', '.tar', '7z',
        '.mp4', '.mkv', '.avi', '.mov', '.mp3', '.wav', '.ogg',
        '.css', '.js', '.xml', '.json', '.csv'
    )

    # Kita akan mencari segmen path 'iklan'
    IGNORED_PATH_SEGMENTS = ('iklan',)

    while pages_to_visit and len(visited_pages) < max_pages:
        current_url = pages_to_visit.popleft()
        
        if current_url in visited_pages:
            continue
        
        try:
            parsed_current_url = urlparse(current_url) # Parse sekali saja
            cleaned_url_path = parsed_current_url.path
        except ValueError:
            print(f"  -> [SKIP] URL tidak valid: {current_url}")
            continue 

        if cleaned_url_path.lower().endswith(IGNORED_EXTENSIONS):
            print(f"  -> [SKIP] Mengabaikan file (dari ekstensi): {current_url}")
            continue
            
        
        # Pecah path menjadi segmen: '/berita/iklan/123' -> ['', 'berita', 'iklan', '123']
        current_path_segments = set(cleaned_url_path.split('/')) 
        
        # Cek apakah ada irisan (intersection) antara segmen path dan segmen yang diabaikan
        if not current_path_segments.isdisjoint(IGNORED_PATH_SEGMENTS):
            print(f"  -> [SKIP] Mengabaikan path terlarang: {current_url}")
            continue
       
            
        visited_pages.add(current_url)
        print(f"[{len(visited_pages)}/{max_pages}] Crawling: {current_url}")
        
        try:
            time.sleep(delay)
            
            try:
                head_response = requests.head(current_url, timeout=3, allow_redirects=True)
                head_response.raise_for_status() 
                content_type = head_response.headers.get('Content-Type', '')
                
                if 'text/html' not in content_type:
                    print(f"  -> [SKIP] Mengabaikan tipe konten non-HTML: {content_type}")
                    continue
            except requests.exceptions.RequestException as head_err:
                if 'head_response' in locals() and head_response.status_code >= 400:
                        print(f"  -> Gagal (HEAD): {current_url}: {head_err}")
                        continue
                pass

            response = requests.get(current_url, timeout=5)
            response.raise_for_status()
            
            final_content_type = response.headers.get('Content-Type', '')
            if 'text/html' not in final_content_type:
                    print(f"  -> [SKIP] Mengabaikan tipe konten non-HTML (setelah GET): {final_content_type}")
                    continue
            
            soup = BeautifulSoup(response.content, 'html.parser')
            links = soup.find_all('a', href=True)
            
            for link in links:
                href = link['href']
                
                if href.startswith(('#', 'javascript:', 'mailto:', 'tel:')) or not href.strip():
                    continue
                
                absolute_url = urljoin(current_url, href)
                absolute_url = absolute_url.split('#')[0] # Hapus fragment

                try:
                    parsed_absolute_url = urlparse(absolute_url)
                    
                    
                    absolute_url_path = parsed_absolute_url.path
                    found_path_segments = set(absolute_url_path.split('/'))
                    
                    if not found_path_segments.isdisjoint(IGNORED_PATH_SEGMENTS):
                        # Jangan tambahkan ke antrian jika path-nya diabaikan
                        continue
                    

                    link_hostname = parsed_absolute_url.hostname
                    if link_hostname and link_hostname.endswith(base_hostname):
                        edge_list.append([current_url, absolute_url])
                        if absolute_url not in visited_pages:
                            pages_to_visit.append(absolute_url)
                except ValueError:
                    # Jika URL yang ditemukan tidak valid
                    continue

        except requests.exceptions.RequestException as e:
            print(f"  -> Gagal mengakses (GET) {current_url}: {str(e)}")
    
    print(f"\nCrawl selesai. Total {len(visited_pages)} halaman di-visit.")
    print(f"Total {len(edge_list)} link (edge) ditemukan.")
    
    if not edge_list:
        print("Tidak ada edge yang ditemukan. DataFrame akan kosong.")
        return pd.DataFrame(columns=["Halaman Sumber", "Link Keluar (Internal)"])
    
    df = pd.DataFrame(edge_list, columns=["Halaman Sumber", "Link Keluar (Internal)"])
    df = df.drop_duplicates().reset_index(drop=True)
    
    print(f"Dataset akhir memiliki {len(df)} edge.")
    
    return df

# --- Bagian Utama untuk Menjalankan Kode ---
if __name__ == "__main__":
    
    target_url = "https://bangsaonline.com/"
    batas_halaman = 100
    
    start_time = time.time()
    
    pagerank_df = build_pagerank_dataset(target_url, max_pages=batas_halaman, delay=0.1)
    
    end_time = time.time()
    duration = end_time - start_time
    
    if not pagerank_df.empty:
        print("\n--- Contoh Hasil Dataset (Head) ---")
        print(pagerank_df.head(10))
        
        output_filename = "pagerank500_edges_berita_new.csv"
        pagerank_df.to_csv(output_filename, index=False)
        print(f"\nFile berhasil disimpan ke {output_filename}")
    else:
        print("\nDataset akhir kosong, tidak ada file CSV yang disimpan.")

    print(f"\n--- Selesai ---")
    minutes = int(duration // 60)
    seconds = int(duration % 60)
    print(f"Total waktu eksekusi: {minutes} menit {seconds} detik ({duration:.2f} detik)")
# Out:
# Memulai crawl dari: https://bangsaonline.com/
# Domain target: bangsaonline.com
# Batas halaman: 100
#
# [1/100] Crawling: https://bangsaonline.com/
# [2/100] Crawling: https://bangsaonline.com
# [3/100] Crawling: https://bangsaonline.com/user/registration
#   -> Gagal (HEAD): https://bangsaonline.com/user/registration: 500 Server Error: Internal Server Error for url: https://bangsaonline.com/user/registration
# [4/100] Crawling: https://bangsaonline.com/feed/
#   -> [SKIP] Mengabaikan tipe konten non-HTML: application/xml
# [5/100] Crawling: https://bangsaonline.com/live
# [6/100] Crawling: https://bangsaonline.com/kanal/jawa-timur
# [7/100] Crawling: https://bangsaonline.com/kanal/jatim-metro
# [8/100] Crawling: https://bangsaonline.com/kanal/jatim-tengah
# [9/100] Crawling: https://bangsaonline.com/kanal/jatim-utara
# [10/100] Crawling: https://bangsaonline.com/kanal/jatim-selatan
# [11/100] Crawling: https://bangsaonline.com/kanal/jatim-timur
# [12/100] Crawling: https://bangsaonline.com/kanal/jatim-barat
# [13/100] Crawling: https://bangsaonline.com/kanal/jatim-madura
# [14/100] Crawling: https://bangsaonline.com/kanal/nasional
# [15/100] Crawling: https://bangsaonline.com/kanal/nusantara
# [16/100] Crawling: https://bangsaonline.com/kanal/politik
# [17/100] Crawling: https://bangsaonline.com/kanal/birokrasi
# [18/100] Crawling: https://bangsaonline.com/kanal/religia
# [19/100] Crawling: https://bangsaonline.com/kanal/tj-islam-sehari-hari
# [20/100] Crawling: https://bangsaonline.com/kanal/tafsir-al-quran-aktual
# [21/100] Crawling: https://bangsaonline.com/kanal/pesantren
# [22/100] Crawling: https://bangsaonline.com/kanal/ormas
# [23/100] Crawling: https://bangsaonline.com/kanal/hukum-dan-kriminal
# [24/100] Crawling: https://bangsaonline.com/kanal/ekonomi
# [25/100] Crawling: https://bangsaonline.com/kanal/entrepreneur
# [26/100] Crawling: https://bangsaonline.com/kanal/entertain-sport
# [27/100] Crawling: https://bangsaonline.com/kanal/selebriti
# [28/100] Crawling: https://bangsaonline.com/kanal/wisata
# [29/100] Crawling: https://bangsaonline.com/kanal/lifestyle
# [30/100] Crawling: https://bangsaonline.com/kanal/olahraga
# [31/100] Crawling: https://bangsaonline.com/kanal/otomotif
# [32/100] Crawling: http://www.bangsaonline.com/berita-video
# [33/100] Crawling: https://bangsaonline.com/kanal/pendidikan
# [34/100] Crawling: https://bangsaonline.com/kanal/kesehatan
# [35/100] Crawling: https://bangsaonline.com/kanal/tren
# [36/100] Crawling: https://bangsaonline.com/kanal/kuliner
# [37/100] Crawling: https://bangsaonline.com/kanal/figur
# [38/100] Crawling: https://bangsaonline.com/kanal/sejarah-dan-budaya
# [39/100] Crawling: https://bangsaonline.com/kanal/internasional
# [40/100] Crawling: https://bangsaonline.com/kanal/unik-aneh
# [41/100] Crawling: https://bangsaonline.com/kanal/peristiwa
# [42/100] Crawling: https://bangsaonline.com/kanal/teknologi
# [43/100] Crawling: https://bangsaonline.com/kanal/komunitas-dan-lingkungan
# [44/100] Crawling: http://www.bangsaonline.com/indeks
# [45/100] Crawling: https://bangsaonline.com/berita/156575/mengembalikan-nu-kepada-para-kiai-sepuh-bukan-kiai-kampungan
# [46/100] Crawling: https://bangsaonline.com/kanal/opini
# [47/100] Crawling: https://bangsaonline.com/berita/156466/tafsir-al-hajj-28-29-hilah-dalam-nadzar
# [48/100] Crawling: https://bangsaonline.com/berita-video/156056/pemkab-malang-dan-bea-cukai-musnahkan-32-juta-batang-rokok-ilegal-1
# [49/100] Crawling: https://bangsaonline.com/berita-video/
# [50/100] Crawling: https://bangsaonline.com/berita/154277/tafsir-al-hajj-24-25-fiqh-al-haram
# [51/100] Crawling: https://bangsaonline.com/berita/156563/dugaan-korupsi-dana-blud-rsud-moh-zyn-kejari-sampang-ungkap-peluang-lebih-dari-1-tersangka
# [52/100] Crawling: https://bangsaonline.com/berita/156582/bea-cukai-sidoarjo-musnahkan-93-juta-batang-rokok-ilegal-senilai-rp139-miliar
# [53/100] Crawling: https://bangsaonline.com/berita/156580/lewat-sosialisasi-ekspor-impor-wali-kota-mojokerto-dorong-ikm-ukm-naik-kelas
# [54/100] Crawling: https://bangsaonline.com/berita/156576/asn-protes-ke-polres-situbondo-tuntut-penahanan-tersangka-pengeroyokan
# [55/100] Crawling: https://bangsaonline.com/berita/156573/harga-sembako-di-jatim-terus-menunjukkan-penurunan-hari-ini-cabai-rawit-merosot-rp7-ribu
# [56/100] Crawling: https://bangsaonline.com/berita/156565/dinas-pendidikan-dan-kebudayaan-kota-pasuruan-mengucapkan-selamat-hari-ibu
# [57/100] Crawling: https://bangsaonline.com/berita/156585/pergerakan-harga-emas-lotus-archi-hari-ini-1-gram-naik-rp12-ribu
# [58/100] Crawling: https://bangsaonline.com/berita/156583/wamendag-tinjau-harga-pangan-di-mojokerto-jelang-nataru
# [59/100] Crawling: https://bangsaonline.com/berita/156584/dalam-sepekan-emas-galeri24-naik-rp69-ribu-simak-harga-selengkapnya-berikut-ini
# [60/100] Crawling: https://bangsaonline.com/berita/156581/harga-pangan-aceh-18-desember-2025-rawit-hijau-dan-cabai-keriting-turun-drastis-telur-bawang-naik
# [61/100] Crawling: https://bangsaonline.com/berita/156579/sambut-tahun-baru-2026-mui-sukolilo-gelar-doa-bersama
# [62/100] Crawling: https://bangsaonline.com/berita/156578/merosot-lagi-harga-cabai-rawit-di-surabaya-hari-ini-turun-rp7-300
# [63/100] Crawling: https://bangsaonline.com/berita/156577/skrining-riwayat-kesehatan-di-mobile-jkn-dorong-deteksi-dini-penyakit-kronis
# [64/100] Crawling: https://bangsaonline.com/berita/156574/perkuat-pembinaan-atlet-pelajar-pemprov-jatim-revitalisasi-smanor-sidoarjo
# [65/100] Crawling: https://bangsaonline.com/berita/156572/kiai-asep-undang-1-936-kepala-sekolah-di-jatim-bongkar-rahasia-sukses-amanatul-ummah
# [66/100] Crawling: https://bangsaonline.com/berita/156446/prakiraan-cuaca-sidoarjo-hari-ini-kamis-18-desember-2025-suhu-24-31°c-kecepatan-angin-3-8-ms
# [67/100] Crawling: https://bangsaonline.com/berita/156560/korban-banjir-sumatera-akan-terima-bantuan-rp3-juta-untuk-perabotan-rumah
# [68/100] Crawling: https://bangsaonline.com/berita/156448/prakiraan-cuaca-jombang-hari-ini-kamis-18-desember-2025-suhu-23-31°c-kecepatan-angin-4-2-ms
# [69/100] Crawling: https://bangsaonline.com/berita/156570/pt-sig-pabrik-tuban-rehab-rumah-milik-lansia-di-merakurak
# [70/100] Crawling: https://bangsaonline.com/berita/156568/gus-dur-stempel-digital-dan-labirin-modernitas-di-markas-besar-nu-1
# [71/100] Crawling: https://bangsaonline.com/berita/156447/prakiraan-cuaca-trenggalek-hari-ini-kamis-18-desember-2025-suhu-21-29°c-kecepatan-angin-7-6-ms
# [72/100] Crawling: https://bangsaonline.com/berita/156571/festival-kopi-quds-royal-hotel-surabaya-meriahkan-akhir-tahun-dengan-literasi-dan-seni
# [73/100] Crawling: https://bangsaonline.com/berita/156569/pt-freeport-gelar-pelatihan-apartemen-kepiting-sebagai-solusi-alternatif-usaha-nelayan-gresik
# [74/100] Crawling: https://bangsaonline.com/berita/156567/diabetes-dan-hipertensi-meningkat-bpjs-kesehatan-sidoarjo-gencarkan-program-prolanis
# [75/100] Crawling: https://bangsaonline.com/berita/156566/cegah-korupsi-pemkab-lamongan-terapkan-strategi-digitalisasi
# [76/100] Crawling: https://bangsaonline.com/berita/156564/cimb-niaga-fasilitasi-green-financing-syariah-untuk-dukung-keberlanjutan-ikpt
# [77/100] Crawling: https://bangsaonline.com/berita/156562/bupati-madiun-sampaikan-keputusan-hasil-raperdes-apbdes-seluruh-desa-teken-pakta-integritas
# [78/100] Crawling: https://bangsaonline.com/berita/156561/pramuka-jatim-salurkan-bantuan-rp605-juta-untuk-bencana-di-sumut-sumbar-dan-aceh
# [79/100] Crawling: https://bangsaonline.com/berita/156559/apresiasi-capaian-positif-pemkab-mojokerto-anugerahkan-22-penghargaan-untuk-opd-dan-asn-berprestasi
# [80/100] Crawling: https://bangsaonline.com/berita/156558/polisi-amankan-dua-pengedar-sabu-asal-bawean-gresik
# [81/100] Crawling: https://bangsaonline.com/berita/156557/mubes-hari-terpilih-jadi-ketua-fprb-kabupaten-kediri-periode-2025–2029
# [82/100] Crawling: https://bangsaonline.com/berita/156556/perkuat-antisipasi-bencana-pemkot-batu-gelar-sarasehan-kewilayahan-jelang-nataru-2026
# [83/100] Crawling: https://bangsaonline.com/berita/156555/pemkab-madiun-gandeng-kejari-sosialisasikan-penerapan-kuhp-nasional
# [84/100] Crawling: https://bangsaonline.com/berita/156554/bnn-kabupaten-pasuruan-razia-psk-di-prigen-1-orang-positif-narkoba
# [85/100] Crawling: https://bangsaonline.com/berita/156553/meski-sudah-sidang-dan-kapolres-minta-maaf-salah-tangkap-polres-blitar-masih-picu-amarah-masyarakat
# [86/100] Crawling: https://bangsaonline.com/tag/harga-emas
# [87/100] Crawling: https://bangsaonline.com/tag/desa-gresik
# [88/100] Crawling: https://bangsaonline.com/tag/polda-jatim
# [89/100] Crawling: https://bangsaonline.com/tag/kiai-asep
# [90/100] Crawling: https://bangsaonline.com/tag/kediri
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://bangsaonline.com/images/uploads/ekoran/fb375dfde274a8f63859663208622bb3.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://bangsaonline.com/images/uploads/ekoran/8cd8c8590dce2bbb0b62270da4117e38.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://bangsaonline.com/images/uploads/ekoran/0263bf34886b96dfeae8a8ace013a722.jpg
#   -> [SKIP] Mengabaikan file (dari ekstensi): https://bangsaonline.com/images/uploads/ekoran/94b79402f31a4b9de1a770654c75eaeb.jpg
# [91/100] Crawling: https://bangsaonline.com/ekoran
# [92/100] Crawling: https://bangsaonline.com/berita/156519/di-uin-jakarta-kiai-asep-ungkap-kunci-sukses-mengajar-murid-seperti-anak-cari-ikan-di-sungai
# [93/100] Crawling: https://bangsaonline.com/berita/156359/kiai-asep-terkejut-dapat-penghargaan-dari-kpai-sebagai-tokoh-peduli-anak
# [94/100] Crawling: https://bangsaonline.com/berita/156382/forum-muktamar-tebuireng-2025-turats-nabawi-desak-pemerintah-tinjau-ulang-hilirisasi-sda
# [95/100] Crawling: https://bangsaonline.com/kanal/jawa-barat
# [96/100] Crawling: https://bangsaonline.com/kanal/jawa-tengah
# [97/100] Crawling: https://bangsaonline.com/kanal/dki-jakarta
# [98/100] Crawling: https://bangsaonline.com/kanal/di-yogyakarta
# [99/100] Crawling: https://bangsaonline.com/kanal/banten
# [100/100] Crawling: https://bangsaonline.com/kanal/bali
#
# Crawl selesai. Total 100 halaman di-visit.
# Total 14140 link (edge) ditemukan.
# Dataset akhir memiliki 10383 edge.
#
# --- Contoh Hasil Dataset (Head) ---
#               Halaman Sumber                        Link Keluar (Internal)
# 0  https://bangsaonline.com/                      https://bangsaonline.com
# 1  https://bangsaonline.com/    https://bangsaonline.com/user/registration
# 2  https://bangsaonline.com/                https://bangsaonline.com/feed/
# 3  https://bangsaonline.com/                 https://bangsaonline.com/live
# 4  https://bangsaonline.com/                     https://bangsaonline.com/
# 5  https://bangsaonline.com/     https://bangsaonline.com/kanal/jawa-timur
# 6  https://bangsaonline.com/    https://bangsaonline.com/kanal/jatim-metro
# 7  https://bangsaonline.com/   https://bangsaonline.com/kanal/jatim-tengah
# 8  https://bangsaonline.com/    https://bangsaonline.com/kanal/jatim-utara
# 9  https://bangsaonline.com/  https://bangsaonline.com/kanal/jatim-selatan
#
# File berhasil disimpan ke pagerank500_edges_berita_new.csv
#
# --- Selesai ---
# Total waktu eksekusi: 0 menit 58 detik (58.11 detik)
