# %% [markdown]
# # Link Graph Scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
BASE_URL = "https://pta.trunojoyo.ac.id"
START_URL = "https://pta.trunojoyo.ac.id/c_search/byprod/7" # Manajemen
headers = {"User-Agent": "Mozilla/5.0"}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

BASE_URL = "https://pta.trunojoyo.ac.id"
START_URL = "https://pta.trunojoyo.ac.id/c_search/byprod/7"
headers = {"User-Agent": "Mozilla/5.0"}

def get_internal_links(url):
    """Ambil semua link internal dari satu halaman"""
    try:
        r = requests.get(url, headers=headers, timeout=10)
        r.raise_for_status()
        soup = BeautifulSoup(r.text, "html.parser")
        links = []
        for a in soup.find_all("a", href=True):
            href = a["href"]
            if href.startswith("/") or href.startswith(BASE_URL):
                if not href.startswith("javascript"):
                    if href.startswith("/"):
                        href = BASE_URL + href
                    links.append(href.split("#")[0])
        return list(set(links))
    except Exception as e:
        print(f"Error akses {url}: {e}")
        return []

def crawl_graph(start_url, max_pages=10):
    visited = set()
    to_visit = [start_url]
    edges = []

    while to_visit and len(visited) < max_pages:
        current = to_visit.pop(0)
        if current in visited:
            continue
        visited.add(current)
        print(f"Crawling: {current}")

        links = get_internal_links(current)
        for link in links:
            edges.append({"source": current, "target": link})
            if link not in visited and link not in to_visit:
                to_visit.append(link)

    return edges

# Jalankan crawler
edges = crawl_graph(START_URL, max_pages=10)

# Simpan hasil
df = pd.DataFrame(edges)
df.to_csv("pta_graph.csv", index=False)  # atau gunakan to_excel("pta_graph.xlsx", index=False, engine="openpyxl")
print("✅ File berhasil disimpan.")
# Out:
# Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/7
# Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/21
# Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/22
# Crawling: https://pta.trunojoyo.ac.id/c_search/byfac/4
# Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/32
# Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/19
# Crawling: https://pta.trunojoyo.ac.id/welcome/detail/090211200001
# Crawling: https://pta.trunojoyo.ac.id/c_search/byfac/1
# Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/2
# Crawling: https://pta.trunojoyo.ac.id/c_search/byprod/6
# ✅ File berhasil disimpan.

# %%
df
# Out:
#                                             source  \
# 0    https://pta.trunojoyo.ac.id/c_search/byprod/7
# 1    https://pta.trunojoyo.ac.id/c_search/byprod/7
# 2    https://pta.trunojoyo.ac.id/c_search/byprod/7
# 3    https://pta.trunojoyo.ac.id/c_search/byprod/7
# 4    https://pta.trunojoyo.ac.id/c_search/byprod/7
# ..                                             ...
# 612  https://pta.trunojoyo.ac.id/c_search/byprod/6
# 613  https://pta.trunojoyo.ac.id/c_search/byprod/6
# 614  https://pta.trunojoyo.ac.id/c_search/byprod/6
# 615  https://pta.trunojoyo.ac.id/c_search/byprod/6
# 616  https://pta.trunojoyo.ac.id/c_search/byprod/6
#
#                                                 target
# 0       https://pta.trunojoyo.ac.id/c_search/byprod/21
# 1       https://pta.trunojoyo.ac.id/c_search/byprod/22
# 2         https://pta.trunojoyo.ac.id/c_search/byfac/4
# 3       https://pta.trunojoyo.ac.id/c_search/byprod/32
# 4       https://pta.trunojoyo.ac.id/c_search/byprod/19
# ..                                                 ...
# 612     https://pta.trunojoyo.ac.id/c_search/byprod/24
# 613     https://pta.trunojoyo.ac.id/c_search/byprod/99
# 614      https://pta.trunojoyo.ac.id/c_search/byprod/8
# 615     https://pta.trunojoyo.ac.id/c_search/byprod/18
# 616  https://pta.trunojoyo.ac.id/welcome/detail/080...
#
# [617 rows x 2 columns]
